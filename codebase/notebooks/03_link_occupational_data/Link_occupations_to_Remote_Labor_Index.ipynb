# %% [markdown]
# # Linking Remote Labor Index to ESCO occupations
#
# Remote Labor Index ([del Rio-Chanona et al. 2020](https://www.oxfordmartin.ox.ac.uk/publications/supply-and-demand-shocks-in-the-covid-19-pandemic-an-industry-and-occupation-perspective/)) indicates what proportion of occupation's work activities can be performed remotely.
# RLI is provided for US occupations at the six digit SOC code level - hence, we crosswalk these to the full list of O\*NET occupations, and then do another crosswalk to ESCO.
#
# References:
# - Paper by [del Rio-Chanona et al. 2020](https://www.oxfordmartin.ox.ac.uk/publications/supply-and-demand-shocks-in-the-covid-19-pandemic-an-industry-and-occupation-perspective/) where Remote Labor Index was introduced; the table `occupation_variables_and_shock.csv` was accessed and obtained in June 2020 from [here](https://zenodo.org/record/3751068#.X9OxnOmTJTY).
# - Crosswalk between US-SOC and O\*NET (`'2010_to_SOC_Crosswalk.xls'`, accessed and obtained in June 2020. Note that in November 2020, O\*NET released an [updated crosswalk](https://www.onetcenter.org/taxonomy.html))

# %% [markdown]
# # 0. Import dependencies and inputs

# %%
# %run ../notebook_preamble.ipy

# %%
# Import crosswalk from US-SOC to O*NET
soc10_to_onet = pd.read_excel(data_folder + 'raw/onet/2010_to_SOC_Crosswalk.xls',
              sheet_name='O-NET-SOC 2010 Occupation Listi', skiprows=3)
soc10_to_onet = soc10_to_onet.rename(columns={
    'O*NET-SOC 2010 Code': 'onet_code',
    'O*NET-SOC 2010 Title': 'onet_occupation',
    '2010 SOC Code': 'soc_code',
    '2010 SOC Title': 'soc_title'
})
soc10_to_onet.sample()
# Out:
#      onet_code          onet_occupation soc_code  \
# 23  11-3071.01  Transportation Managers  11-3071
#
#                                             soc_title
# 23  Transportation, Storage, and Distribution Mana...

# %%
# Import crosswalk between ESCO and ONET
esco_onet_xwalk = pd.read_csv(data_folder + 'processed/ESCO_ONET_xwalk_full.csv')

# Import the remote labor index
remote_labor_index = pd.read_csv(data_folder + 'raw/remote_labor_index/occupation_variables_and_shock.csv')

# %%
remote_labor_index.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 740 entries, 0 to 739
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   OCC_CODE                   740 non-null    object
#  1   OCC_TITLE                  740 non-null    object
#  2   remote_labor_index         740 non-null    float64
#  3   exposure_infection         644 non-null    float64
#  4   essential_score            740 non-null    float64
#  5   employment                 740 non-null    float64
#  6   median_wage                737 non-null    float64
#  7   mean_wage                  737 non-null    float64
#  8   supply_shock               740 non-null    float64
#  9   demand_shock               740 non-null    float64
#  10  total_shock                740 non-null    float64
#  11  total_shock_with_positive  740 non-null    float64
# dtypes: float64(10), object(2)
# memory usage: 69.5+ KB

# %%
remote_labor_index.sample(5)
# Out:
#     OCC_CODE                                          OCC_TITLE  \
# 34   13-1011  Agents and Business Managers of Artists, Perfo...
# 465  43-5111  Weighers, Measurers, Checkers, and Samplers, R...
# 692  51-9197                                      Tire Builders
# 587  49-9081                   Wind Turbine Service Technicians
# 674  51-9051  Furnace, Kiln, Oven, Drier, and Kettle Operato...
#
#      remote_labor_index  exposure_infection  essential_score  employment  \
# 34             0.538462                 0.0         0.806460     13970.0
# 465            0.294118                 1.0         0.704704     61430.0
# 692            0.000000                 3.0         0.421627     23790.0
# 587            0.000000                 5.0         0.987654      4860.0
# 674            0.250000                14.0         0.175732     15700.0
#
#      median_wage  mean_wage  supply_shock  demand_shock  total_shock  \
# 34       81340.0    86560.0     -0.089326     -0.730601    -0.730601
# 465      41110.0    31080.0     -0.208444     -0.125240    -0.208444
# 692      36470.0    42230.0     -0.578373     -0.099454    -0.578373
# 587      49190.0    54360.0     -0.012346     -0.034877    -0.034877
# 674      30540.0    37600.0     -0.618201     -0.096433    -0.618201
#
#      total_shock_with_positive
# 34                   -0.730601
# 465                  -0.208444
# 692                  -0.578373
# 587                  -0.034877
# 674                  -0.618201

# %%
print(f'Number of unique SOC occupations in "remote_labor_index" dataset: {len(remote_labor_index.OCC_TITLE.unique())}')
print(f'Number of unique SOC occupations in "soc10_to_onet" dataset: {len(soc10_to_onet.soc_title.unique())}')
# Out:
# Number of unique SOC occupations in "remote_labor_index" dataset: 740
# Number of unique SOC occupations in "soc10_to_onet" dataset: 841

# %% [markdown]
# # 1. Link the remote labor index to ESCO occupations

# %%
# Link RLI estimates for 6-digit US SOC to 8-digit ONET occupations
# (we're merging using 'OCC_TITLE', as some values in the 'OCC_CODE' column appears to be corrupted)
onet_to_RLI = soc10_to_onet.merge(remote_labor_index[['OCC_TITLE', 'remote_labor_index', 'essential_score', 'total_shock']],
                    right_on='OCC_TITLE',left_on='soc_title', how='left');
onet_to_RLI.head(3)
# Out:
#     onet_code                  onet_occupation soc_code  \
# 0  11-1011.00                 Chief Executives  11-1011
# 1  11-1011.03    Chief Sustainability Officers  11-1011
# 2  11-1021.00  General and Operations Managers  11-1021
#
#                          soc_title                        OCC_TITLE  \
# 0                 Chief Executives                 Chief Executives
# 1                 Chief Executives                 Chief Executives
# 2  General and Operations Managers  General and Operations Managers
#
#    remote_labor_index  essential_score  total_shock
# 0            0.714286         0.766624    -0.066679
# 1            0.714286         0.766624    -0.066679
# 2            0.705882         0.607782    -0.115358

# %%
onet_to_RLI.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1110 entries, 0 to 1109
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   onet_code           1110 non-null   object
#  1   onet_occupation     1110 non-null   object
#  2   soc_code            1110 non-null   object
#  3   soc_title           1110 non-null   object
#  4   OCC_TITLE           1000 non-null   object
#  5   remote_labor_index  1000 non-null   float64
#  6   essential_score     1000 non-null   float64
#  7   total_shock         1000 non-null   float64
# dtypes: float64(3), object(5)
# memory usage: 78.0+ KB

# %%
onet_to_RLI[onet_to_RLI.remote_labor_index.isnull()]
# Out:
#        onet_code                                    onet_occupation soc_code  \
# 65    13-1021.00        Buyers and Purchasing Agents, Farm Products  13-1021
# 66    13-1022.00  Wholesale and Retail Buyers, Except Farm Products  13-1022
# 67    13-1023.00  Purchasing Agents, Except Wholesale, Retail, a...  13-1023
# 71    13-1032.00                  Insurance Appraisers, Auto Damage  13-1032
# 154   15-2091.00                           Mathematical Technicians  15-2091
# ...          ...                                                ...      ...
# 1105  55-3015.00             Command and Control Center Specialists  55-3015
# 1106  55-3016.00                                           Infantry  55-3016
# 1107  55-3017.00                        Radar and Sonar Technicians  55-3017
# 1108  55-3018.00                                     Special Forces  55-3018
# 1109  55-3019.00  Military Enlisted Tactical Operations and Air/...  55-3019
#
#                                               soc_title OCC_TITLE  \
# 65          Buyers and Purchasing Agents, Farm Products       NaN
# 66    Wholesale and Retail Buyers, Except Farm Products       NaN
# 67    Purchasing Agents, Except Wholesale, Retail, a...       NaN
# 71                    Insurance Appraisers, Auto Damage       NaN
# 154                            Mathematical Technicians       NaN
# ...                                                 ...       ...
# 1105             Command and Control Center Specialists       NaN
# 1106                                           Infantry       NaN
# 1107                        Radar and Sonar Technicians       NaN
# 1108                                     Special Forces       NaN
# 1109  Military Enlisted Tactical Operations and Air/...       NaN
#
#       remote_labor_index  essential_score  total_shock
# 65                   NaN              NaN          NaN
# 66                   NaN              NaN          NaN
# 67                   NaN              NaN          NaN
# 71                   NaN              NaN          NaN
# 154                  NaN              NaN          NaN
# ...                  ...              ...          ...
# 1105                 NaN              NaN          NaN
# 1106                 NaN              NaN          NaN
# 1107                 NaN              NaN          NaN
# 1108                 NaN              NaN          NaN
# 1109                 NaN              NaN          NaN
#
# [110 rows x 8 columns]

# %% [markdown]
# Note that not all O\*NET occupations have been covered by the crosswalk, and hence for these occupations we will not have Remote Labor Index estimates.

# %%
# Link ONET estimates to ESCO
occupations_remote = esco_onet_xwalk.merge(onet_to_RLI[['onet_code', 
                                                        'soc_title', 
                                                        'remote_labor_index', 
                                                        'essential_score',
                                                        'total_shock'
                                                       ]], on='onet_code', how='left')

occupations_remote.sample(3)
# Out:
#         id                                        concept_uri  \
# 954    954  http://data.europa.eu/esco/occupation/4fa660b3...
# 2519  2519  http://data.europa.eu/esco/occupation/d6a395eb...
# 842    842  http://data.europa.eu/esco/occupation/479ede81...
#
#             preferred_label  isco_level_4   onet_code  \
# 954   social work assistant          3412  21-1093.00
# 2519         fight director          3435  27-2032.00
# 842     journalism lecturer          2310  25-1125.00
#
#                           onet_occupation  \
# 954   social and human service assistants
# 2519                       choreographers
# 842       history teachers, postsecondary
#
#                                 soc_title  remote_labor_index  \
# 954   Social and Human Service Assistants            0.615385
# 2519                       Choreographers            0.500000
# 842       History Teachers, Postsecondary            0.850000
#
#       essential_score  total_shock
# 954          0.989138    -0.004178
# 2519         0.725572    -0.219543
# 842          1.000000    -0.000000

# %% [markdown]
# # 2. Check the Remote Labor Index estimates

# %%
occupations_remote.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2942 entries, 0 to 2941
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   id                  2942 non-null   int64
#  1   concept_uri         2942 non-null   object
#  2   preferred_label     2942 non-null   object
#  3   isco_level_4        2942 non-null   int64
#  4   onet_code           2921 non-null   object
#  5   onet_occupation     2921 non-null   object
#  6   soc_title           2921 non-null   object
#  7   remote_labor_index  2782 non-null   float64
#  8   essential_score     2782 non-null   float64
#  9   total_shock         2782 non-null   float64
# dtypes: float64(3), int64(2), object(5)
# memory usage: 252.8+ KB

# %% [markdown]
# ## 2.1 Null values

# %%
# Check which occupations do not have remote labor index estimates
occupations_remote.remote_labor_index.isnull().sum()
# Out:
# 160

# %%
df = occupations_remote[occupations_remote.remote_labor_index.isnull()].sort_values('isco_level_4')[[
    'preferred_label','onet_code', 'isco_level_4', 'onet_occupation']]
for j, row in df.iterrows():
    print(row.isco_level_4, row.preferred_label)
# Out:
# 110 squadron leader
# 110 artillery officer
# 110 colonel
# 110 navy officer
# 110 air force officer
# 110 armed forces officer
# 110 army general
# 110 fleet commander
# 110 army major
# 110 brigadier
# 110 army captain
# 110 lieutenant
# 210 warfare specialist
# 210 sergeant
# 210 special forces officer
# 210 army corporal
# 310 military engineer
# 310 intelligence communications interceptor
# 310 bomb disposal technician
# 310 infantry soldier
# 310 air force pilot
# 2120 gambling, betting, and lottery quality assurance engineer
# 2131 botanist
# 2131 toxicologist
# 2131 botanicals specialist
# 2131 microbiologist
# 2131 curator of horticulture
# 2131 geneticist
# 2131 biophysicist
# 2131 biologist
# 2131 animal feed nutritionist
# 2131 specialist biomedical scientist
# 2131 aquaculture biologist
# 2131 epidemiologist
# 2131 physiologist
# 2131 biomedical scientist advanced
# 2131 biochemist
# 2359 tutor
# 2431 advertising media buyer
# 2659 community artist
# 3111 metrology technician
# 3112 energy conservation officer
# 3113 electromechanical engineering technician
# 3113 calibration technician
# 3113 electrical engineering technician
# 3114 optoelectronic engineering technician
# 3114 avionics inspector
# 3114 instrumentation engineering technician
# 3114 electronics engineering technician
# 3114 computer hardware test technician
# 3114 microsystem engineering technician
# 3114 microelectronics engineering technician
# 3114 sensor engineering technician
# 3114 computer hardware engineering technician
# 3114 medical device engineering technician
# 3118 clothing CAD technician
# 3119 robotics engineering technician
# 3119 automation engineering technician
# 3139 automated assembly line operator
# 3139 clothing process control technician
# 3155 air traffic safety technician
# 3212 anatomical pathology technician
# 3212 medical laboratory assistant
# 3212 cytology screener
# 3212 biomedical scientist
# 3323 textile sourcing merchandiser
# 3323 green coffee buyer
# 3323 costume buyer
# 3323 ICT buyer
# 3323 purchaser
# 3323 timber trader
# 3323 purchase planner
# 3324 wholesale merchant in chemical products
# 3324 wholesale merchant in mining, construction and civil engineering machinery
# 3324 wholesale merchant in office furniture
# 3324 wholesale merchant in textiles and textile semi-finished and raw materials
# 3324 wholesale merchant in fruit and vegetables
# 3324 wholesale merchant in hardware, plumbing and heating equipment and supplies
# 3324 wholesale merchant in beverages
# 3324 wholesale merchant in agricultural machinery and equipment
# 3324 wholesale merchant in live animals
# 3324 wholesale merchant in wood and construction materials
# 3324 wholesale merchant in clothing and footwear
# 3324 wholesale merchant in metals and metal ores
# 3324 wholesale merchant in tobacco products
# 3324 wholesale merchant in flowers and plants
# 3324 wholesale merchant in electrical household appliances
# 3324 wholesale merchant in agricultural raw materials, seeds and animal feeds
# 3324 wholesale merchant in textile industry machinery
# 3324 wholesale merchant in electronic and telecommunications equipment and parts
# 3324 wholesale merchant in hides, skins and leather products
# 3324 wholesale merchant in computers, computer peripheral equipment and software
# 3324 wholesale merchant in pharmaceutical goods
# 3324 wholesale merchant in meat and meat products
# 3324 wholesale merchant in dairy products and edible oils
# 3324 wholesale merchant in machinery, industrial equipment, ships and aircraft
# 3324 wholesale merchant in furniture, carpets and lighting equipment
# 3324 wholesale merchant in sugar, chocolate and sugar confectionery
# 3324 wholesale merchant in household goods
# 3324 wholesale merchant in fish, crustaceans and molluscs
# 3324 wholesale merchant in coffee, tea, cocoa and spices
# 3324 wholesale merchant
# 3324 wholesale merchant in perfume and cosmetics
# 3324 wholesale merchant in china and other glassware
# 3324 wholesale merchant in waste and scrap
# 3324 wholesale merchant in watches and jewellery
# 3324 wholesale merchant in machine tools
# 3324 wholesale merchant in office machinery and equipment
# 3413 monk/nun
# 3421 professional athlete
# 3423 mountain guide
# 3435 flying director
# 3435 prompter
# 3435 pyrotechnician
# 4212 casino gaming manager
# 4212 casino pit boss
# 4212 lottery operator
# 5113 guide
# 5113 environmental education officer
# 5113 zoo educator
# 5113 park guide
# 5161 fortune teller
# 5161 medium
# 5161 psychic
# 5161 astrologer
# 5169 escort
# 5169 dating service consultant
# 5241 art model
# 5241 fashion model
# 6222 fisheries boatman
# 6223 deep-sea fishery worker
# 6223 fisheries boatmaster
# 6223 fisheries master
# 6224 hunter
# 7311 optical instrument repairer
# 7311 optical instrument assembler
# 7317 brush maker
# 7511 slaughterer
# 7511 halal slaughterer
# 7511 kosher slaughterer
# 8159 nonwoven  textile technician
# 8159 nonwoven staple machine operator
# 8160 prepared meat operator
# 8212 electrical equipment assembler
# 8212 electrical cable assembler
# 8212 semiconductor processor
# 8212 electronic musical instrument maker
# 8212 battery assembler
# 8212 control panel assembler
# 8212 wire harness assembler
# 8212 photographic equipment assembler
# 8212 electromechanical equipment assembler
# 8212 printed circuit board assembler
# 8212 electronic equipment assembler
# 8219 metal products assembler
# 8219 furniture assembler
# 8342 dredge operator
# 8350 fisheries deckhand
# 9216 on foot aquatic resources collector
# 9333 stevedore superintendent

# %% [markdown]
# ## 2.2 Check the Remote Labor Index estimates for ESCO occupations
#
# Note that the dataset also includes an estimate of whether the occupation could be considered 'essential'. We, however, don't use this variable in the final analyses of the Mapping Career Causeways research report.

# %%
# RLI vs 4-digit ISCO-08 code
fig = px.scatter(occupations_remote, y='remote_labor_index', x='isco_level_4',
                 hover_data = ['id','preferred_label','soc_title', 'total_shock'],
                 color_continuous_scale='reds',
                 color='essential_score', title='Remote Labor Index for ESCO occupations')
fig.show()
# Out:
# <div>
#
#
#             <div id="c3ad40e3-87bf-4610-b2ec-22cae1c27e90" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("c3ad40e3-87bf-4610-b2ec-22cae1c27e90")) {
#                     Plotly.newPlot(
#                         'c3ad40e3-87bf-4610-b2ec-22cae1c27e90',
#                         [{"customdata": [[0, "technical director", "Art Directors", -0.13223181651683874], [1, "metal drawing machine operator", "Extruding and Drawing Machine Setters, Operators, and Tenders, Metal and Plastic", -0.3473558544100055], [2, "precision device inspector", "Inspectors, Testers, Sorters, Samplers, and Weighers", -0.4568930450890014], [3, "air traffic safety technician", "Electrical and Electronic Engineering Technicians", null], [4, "hospitality revenue manager", "Market Research Analysts and Marketing Specialists", -0.0456612685559129], [5, "medical laboratory assistant", "Medical and Clinical Laboratory Technicians", null], [6, "asphalt laboratory technician", "Chemical Engineers", -0.061158657011191615], [7, "primary school teaching assistant", "Teacher Assistants", -0.0030711094433521074], [8, "physiotherapist", "Physical Therapists", -0.008292598461577191], [9, "performing arts theatre instructor", "History Teachers, Postsecondary", -0.0], [10, "hydrogenation machine operator", "Separating, Filtering, Clarifying, Precipitating, and Still Machine Setters, Operators, and Tenders", -0.12271976888154244], [11, "pasta operator", "Food Batchmakers", -0.11101625245051537], [12, "tobacco shop manager", "First-Line Supervisors of Retail Sales Workers", -0.3375080480460633], [13, "rental service representative in machinery, equipment and tangible goods", "Counter and Rental Clerks", -0.2627407279991017], [14, "mine surveyor", "Surveyors", -0.011586652583627885], [15, "food safety specialist", "Occupational Health and Safety Specialists", -0.09332560781051402], [16, "land-based machinery technician", "Farm Equipment Mechanics and Service Technicians", -0.6191613958737043], [17, "bus driver", "Bus Drivers, Transit and Intercity", -0.29993747419335803], [18, "import export manager in meat and meat products", "Transportation, Storage, and Distribution Managers", -0.26997483561969304], [19, "housing policy officer", "Management Analysts", -0.013009115375559759], [20, "head chef", "Chefs and Head Cooks", -0.6823232968612729], [21, "nonwoven filament machine operator", "Extruding and Drawing Machine Setters, Operators, and Tenders, Metal and Plastic", -0.3473558544100055], [22, "head of higher education institutions", "Education Administrators, Elementary and Secondary School", -0.0], [23, "insulation supervisor", "First-Line Supervisors of Construction Trades and Extraction Workers", -0.21664136602480205], [24, "dismantling engineer", "Industrial Engineering Technicians", -0.2519657611734017], [25, "insurance claims handler", "Claims Adjusters, Examiners, and Investigators", -0.008336325815134221], [26, "clothing development manager", "Natural Sciences Managers", -0.008978249873561217], [27, "nitroglycerin separator operator", "Chemical Equipment Operators and Tenders", -0.09847365829640577], [28, "biomedical engineer", "Engineers, All Other", -0.1160985610438852], [29, "legal guardian", "Social and Human Service Assistants", -0.004177882572956749], [30, "weaver", "Textile Knitting and Weaving Machine Setters, Operators, and Tenders", -0.6236996835757472], [31, "tile fitter", "Tile and Marble Setters", -0.5289836792014138], [32, "shoe and leather accessories shop manager", "First-Line Supervisors of Retail Sales Workers", -0.3375080480460633], [33, "tour operators manager", "Travel Agents", -0.415608881330388], [34, "bee breeder", "Animal Breeders", -0.08514285714285719], [35, "legal administrative assistant", "Legal Secretaries", -0.0061623266266002535], [36, "petroleum pump system operator", "Petroleum Pump System Operators, Refinery Operators, and Gaugers", -0.2402034588868717], [37, "protective clothing apparel manufacturer", "Sewing Machine Operators", -0.5815164351399921], [38, "coating machine operator", "Plating and Coating Machine Setters, Operators, and Tenders, Metal and Plastic", -0.8315901636648864], [39, "aquaculture hatchery manager", "First-Line Supervisors of Farming, Fishing, and Forestry Work ...

# %% [markdown]
# # 3. Export

# %%
# Export the linked data
occupations_remote.to_csv(data_folder + 'processed/linked_data/ESCO_occupations_Remote_Labor_Index.csv', index=False)
