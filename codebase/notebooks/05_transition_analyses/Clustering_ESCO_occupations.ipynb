# %% [markdown]
# # Clustering of ESCO occupations
#
# To find and analyse groups of related occupations that share similar job requirements and work characteristics, we applied clustering to the newly obtained occupation similarity values. The resulting grouping of occupations organises the 2942 ESCO occupations at two hierarchical levels – which we call skills-based sectors and sub-sectors – with 14 groups at the first level and 54 groups at the second level.
#
# For more details on the clustering methodology, consult pp. 98-102 of the Mapping Career Causeways report.

# %% [markdown]
# # 0. Import dependencies and inputs

# %%
# %run ../notebook_preamble.ipy

import mapping_career_causeways.cluster_utils as cluster_utils
import mapping_career_causeways.cluster_profiling_utils as cluster_profiling_utils

data = load_data.Data()

# %%
# Import the occupation similarity matrix
# W_combined = load_data.Similarities().W_combined
W_combined = np.load('/Users/karliskanders/Documents/career_causeways/data/processed/sim_matrices/occupationSimilarity_Combined_old.npy')

# Create a symmetric similarity matrix for clustering
W_cluster = 0.5*W_combined + 0.5*W_combined.T
W_cluster.shape
# Out:
# (2942, 2942)

# %%
# Number of occupations
n_occ = W_cluster.shape[0]

# %% [markdown]
# # 1. Set up clustering parameters

# %%
# Name of this clustering session
session_name = 'ESCO_occ_v1'
# Number of nearest neighbours used for the graph construction
nearest_neighbours = [15, 20, 25, 30, 60]
# Ensemble size for the first step
N = 1000
# Ensemble size for the consensus step
N_consensus = 100
# Number of clustering trials for each nearest neighbour value
N_nn = N // len(nearest_neighbours)
# Which clusters to break down from the partition
clusters = 'all' # Either a list of integers, or 'all'
# Path to save the clustering results
fpath = f'{data_folder}interim/raw_clustering/ESCO_occ_v1/'

clustering_params = {
    'N': N,
    'N_consensus': N_consensus,
    'N_nn': N_nn,
    'clusters': clusters,
    'fpath': fpath,
    'session_name': session_name,
    'nearest_neighbours': nearest_neighbours}

# %% [markdown]
# # 2. Perform two steps of clustering

# %% [markdown]
# ## 2.1 Level-1

# %%
# Prepare and save the Level-0 partition file (all in one cluster)
partition_df = pd.DataFrame()
partition_df['id'] = data.occupations.id.to_list()
partition_df['cluster'] = np.zeros((len(data.occupations)))
partition_df.to_csv(fpath+session_name+'_clusters_Level0.csv')

# Set the random_state variable for reproduciblity
clustering_params['random_state'] = 14523

# %%
# Perform the clustering
cluster_utils.subcluster_nodes(W=W_cluster, l=0, **clustering_params)
# Out:
# ==============
# Partitioning cluster 0.0...
# Building the graph... done!
# Clustering graph with 15 nearest-neighbours...
# Setting random seeds...
# Generating an ensemble with 200 partitions...
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Elapsed time:  24.00 seconds
# Building the graph... done!
# Clustering graph with 20 nearest-neighbours...
# Setting random seeds...
# Generating an ensemble with 200 partitions...
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Elapsed time:  23.00 seconds
# Building the graph... done!
# Clustering graph with 25 nearest-neighbours...
# Setting random seeds...
# Generating an ensemble with 200 partitions...
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Elapsed time:  25.00 seconds
# Building the graph... done!
# Clustering graph with 30 nearest-neighbours...
# Setting random seeds...
# Generating an ensemble with 200 partitions...
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Elapsed time:  26.00 seconds
# Building the graph... done!
# Clustering graph with 60 nearest-neighbours...
# Setting random seeds...
# Generating an ensemble with 200 partitions...
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Elapsed time:  45.00 seconds
# Clustering the consensus partition...
# Setting random seeds...
# Using co-occurrence matrix to do consensus clustering...
# Building the graph... done!
# Setting random seeds...
# Generating an ensemble with 100 partitions...
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Average pairwise AMI across 100 partitions is 0.9902
# Clustering with 2942 nodes and 14 clusters.
# Elapsed time: 196 seconds

# %%
# Collect subclusters into one partition
partition_1 = cluster_utils.collect_subclusters(0, fpath, session_name, n_total=n_occ)

# Check that partition contains all nodes
len(partition_1)
# Out:
# Final partition saved in /Users/karliskanders/Documents/mapping-career-causeways/codebase/data/interim/raw_clustering/ESCO_occ_v1/ESCO_occ_v1_clusters_Level1.csv
# 2942

# %%
# Check a summary clustering result
cluster_utils.ConsensusClustering.describe_partition(partition_1.cluster.values)
# Out:
# Clustering with 2942 nodes and 14 clusters.
# {'n': 14,
#  'sizes': [600, 426, 322, 272, 237, 185, 178, 145, 129, 124, 89, 87, 74, 74]}

# %%
# Check a summary clustering result
cluster_utils.ConsensusClustering.describe_partition(partition_1.cluster.values)
# Out:
# Clustering with 2942 nodes and 14 clusters.
# {'n': 14,
#  'sizes': [600, 470, 323, 272, 237, 186, 179, 145, 129, 89, 87, 77, 74, 74]}

# %% [markdown]
# ## 2.2 Level-2 clusters

# %%
# Load the partition that we wish to further split apart
partition = pd.read_csv(fpath + session_name + '_clusters_Level1.csv')

# Set the random_state variable for reproduciblity
clustering_params['random_state'] = 1

# %%
# Check that we have all the nodes
len(partition)
# Out:
# 2942

# %%
clustering_params
# Out:
# {'N': 1000,
#  'N_consensus': 100,
#  'N_nn': 200,
#  'clusters': 'all',
#  'fpath': '../../data/interim/raw_clustering/ESCO_occ_v1/',
#  'session_name': 'ESCO_occ_v1',
#  'nearest_neighbours': [15, 20, 25, 30, 60],
#  'random_state': 1}

# %%
# Perform the clustering
cluster_utils.subcluster_nodes(W=W_cluster, l=1, **clustering_params)
# Out:
# ==============
# Partitioning cluster 0...
# Building the graph... done!
# Clustering graph with 15 nearest-neighbours...
# Setting random seeds...
# Generating an ensemble with 200 partitions...
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Elapsed time:  3.00 seconds
# Building the graph... done!
# Clustering graph with 20 nearest-neighbours...
# Setting random seeds...
# Generating an ensemble with 200 partitions...
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Elapsed time:  4.00 seconds
# Building the graph... done!
# Clustering graph with 25 nearest-neighbours...
# Setting random seeds...
# Generating an ensemble with 200 partitions...
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Elapsed time:  4.00 seconds
# Building the graph... done!
# Clustering graph with 30 nearest-neighbours...
# Setting random seeds...
# Generating an ensemble with 200 partitions...
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Elapsed time:  5.00 seconds
# Building the graph... done!
# Clustering graph with 60 nearest-neighbours...
# Setting random seeds...
# Generating an ensemble with 200 partitions...
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Elapsed time:  9.00 seconds
# Clustering the consensus partition...
# Setting random seeds...
# Using co-occurrence matrix to do consensus clustering...
# Building the graph... done!
# Setting random seeds...
# Generating an ensemble with 100 partitions...
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Average pairwise AMI across 100 partitions is 0.9998
# Clustering with 600 nodes and 6 clusters.
# Elapsed time: 36 seconds
# ==============
# Partitioning cluster 1...
# Building the graph... done!
# Clustering graph with 15 nearest-neighbours...
# Setting random seeds...
# Generating an ensemble with 200 partitions...
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Elapsed time:  3.00 seconds
# Building the graph... done!
# Clustering graph with 20 nearest-neighbours...
# Setting random seeds...
# Generating an ensemble with 200 partitions...
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Elapsed time:  4.00 seconds
# Building the graph... done!
# Clustering graph with 25 nearest-neighbours...
# Setting random seeds...
# Generating an ensemble with 200 partitions...
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Elapsed time:  8.00 seconds
# Building the graph... done!
# Clustering graph with 30 nearest-neighbours...
# Setting random seeds...
# Generating an ensemble with 200 partitions...
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Elapsed time:  8.00 seconds
# Building the graph... done!
# Clustering graph with 60 nearest-neighbours...
# Setting random seeds...
# Generating an ensemble with 200 partitions...
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Elapsed time:  9.00 seconds
# Clustering the consensus partition...
# Setting random seeds...
# Using co-occurrence matrix to do consensus clustering...
# Building the graph... done!
# Setting random seeds...
# Generating an ensemble with 100 partitions...
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Average pairwise AMI across 100 partitions is 0.9822
# Clustering with 426 nodes and 5 clusters.
# Elapsed time: 24 seconds
# ==============
# Partitioning cluster 2...
# Building the graph... done!
# Clustering graph with 15 nearest-neighbours...
# Setting random seeds...
# Generating an ensemble with 200 partitions...
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Elapsed time:  2.00 seconds
# Building the graph... done!
# Clustering graph with 20 nearest-neighbours...
# Setting random seeds...
# Generating an ensemble with 200 partitions...
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Elapsed time:  2.00 seconds
# Building the graph... done!
# Clustering graph with 25 nearest-neighbours...
# Setting random seeds...
# Generating an ensemble with 200 partitions...
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Elapsed time:  3.00 seconds
# Building the graph... done!
# Clustering graph with 30 nearest-neighbours...
# Setting random seeds...
# Generating an ensemble with 200 partitions...
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Elapsed time:  3.00 seconds
# Building the graph... done!
# Clustering graph with 60 nearest-neighbours...
# Setting random seeds...
# Generating an ensemble with 200 partitions...
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Elapsed time:  4.00 seconds
# Clustering the consensus partition...
# Setting random seeds...
# Using co-occurrence matrix to do consensus clustering...
# Building the graph... done!
# Setting random seeds...
# Generating an ensemble with 100 partitions...
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Average pairwise AMI across 100 partitions is 0.9959
# Clustering with 322 nodes and 5 clusters.
# Elapsed time: 21 seconds
# ==============
# Partitioning cluster 3...
# Building the graph... done!
# Clustering graph with 15 nearest-neighbours...
# Setting random seeds...
# Generating an ensemble with 200 partitions...
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Elapsed time:  2.00 seconds
# Building the graph... done!
# Clustering graph with 20 nearest-neighbours...
# Setting random seeds...
# Generating an ensemble with 200 partitions...
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Elapsed time:  2.00 seconds
# Building the graph... done!
# Clustering graph with 25 nearest-neighbours...
# Setting random seeds...
# Generating an ensemble with 200 partitions...
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Elapsed time:  2.00 seconds
# Building the graph... done!
# Clustering graph with 30 nearest-neighbours...
# Setting random seeds...
# Generating an ensemble with 200 partitions...
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Elapsed time:  2.00 seconds
# Building the graph... done!
# Clustering graph with 60 nearest-neighbours...
# Setting random seeds...
# Generating an ensemble with 200 partitions...
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Elapsed time:  4.00 seconds
# Clustering the consensus partition...
# Setting random seeds...
# Using co-occurrence matrix to do consensus clustering...
# Building the graph... done!
# Setting random seeds...
# Generating an ensemble with 100 partitions...
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Average pairwise AMI across 100 partitions is 0.9744
# Clustering with 272 nodes and 4 clusters.
# Elapsed time: 19 seconds
# ==============
# Partitioning cluster 4...
# Building the graph... done!
# Clustering graph with 15 nearest-neighbours...
# Setting random seeds...
# Generating an ensemble with 200 partitions...
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Elapsed time:  1.00 seconds
# Building the graph... done!
# Clustering graph with 20 nearest-neighbours...
# Setting random seeds...
# Generating an ensemble with 200 partitions...
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Elapsed time:  2.00 seconds
# Building the graph... done!
# Clustering graph with 25 nearest-neighbours...
# Setting random seeds...
# Generating an ensemble with 200 partitions...
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Elapsed time:  2.00 seconds
# Building the graph... done!
# Clustering graph with 30 nearest-neighbours...
# Setting random seeds...
# Generating an ensemble with 200 partitions...
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Elapsed time:  2.00 seconds
# Building the graph... done!
# Clustering graph with 60 nearest-neighbours...
# Setting random seeds...
# Generating an ensemble with 200 partitions...
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Elapsed time:  3.00 seconds
# Clustering the consensus partition...
# Setting random seeds...
# Using co-occurrence matrix to do consensus clustering...
# Building the graph... done!
# Setting random seeds...
# Generating an ensemble with 100 partitions...
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Average pairwise AMI across 100 partitions is 0.9992
# Clustering with 237 nodes and 3 clusters.
# Elapsed time: 17 seconds
# ==============
# Partitioning cluster 5...
# Building the graph... done!
# Clustering graph with 15 nearest-neighbours...
# Setting random seeds...
# Generating an ensemble with 200 partitions...
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Elapsed time:  1.00 seconds
# Building the graph... done!
# Clustering graph with 20 nearest-neighbours...
# Setting random seeds...
# Generating an ensemble with 200 partitions...
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Elapsed time:  1.00 seconds
# Building the graph... done!
# Clustering graph with 25 nearest-neighbours...
# Setting random seeds...
# Generating an ensemble with 200 partitions...
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Elapsed time:  1.00 seconds
# Building the graph... done!
# Clustering graph with 30 nearest-neighbours...
# Setting random seeds...
# Generating an ensemble with 200 partitions...
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Elapsed time:  1.00 seconds
# Building the graph... done!
# Clustering graph with 60 nearest-neighbours...
# Setting random seeds...
# Generating an ensemble with 200 partitions...
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Elapsed time:  2.00 seconds
# Clustering the consensus partition...
# Setting random seeds...
# Using co-occurrence matrix to do consensus clustering...
# Building the graph... done!
# Setting random seeds...
# Generating an ensemble with 100 partitions...
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Average pairwise AMI across 100 partitions is 1.0
# Clustering with 185 nodes and 5 clusters.
# Elapsed time: 18 seconds
# ==============
# Partitioning cluster 6...
# Building the graph... done!
# Clustering graph with 15 nearest-neighbours...
# Setting random seeds...
# Generating an ensemble with 200 partitions...
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Elapsed time:  1.00 seconds
# Building the graph... done!
# Clustering graph with 20 nearest-neighbours...
# Setting random seeds...
# Generating an ensemble with 200 partitions...
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Elapsed time:  2.00 seconds
# Building the graph... done!
# Clustering graph with 25 nearest-neighbours...
# Setting random seeds...
# Generating an ensemble with 200 partitions...
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Elapsed time:  2.00 seconds
# Building the graph... done!
# Clustering graph with 30 nearest-neighbours...
# Setting random seeds...
# Generating an ensemble with 200 partitions...
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Elapsed time:  2.00 seconds
# Building the graph... done!
# Clustering graph with 60 nearest-neighbours...
# Setting random seeds...
# Generating an ensemble with 200 partitions...
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Elapsed time:  3.00 seconds
# Clustering the consensus partition...
# Setting random seeds...
# Using co-occurrence matrix to do consensus clustering...
# Building the graph... done!
# Setting random seeds...
# Generating an ensemble with 100 partitions...
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Average pairwise AMI across 100 partitions is 1.0
# Clustering with 178 nodes and 4 clusters.
# Elapsed time: 16 seconds
# ==============
# Partitioning cluster 7...
# Building the graph... done!
# Clustering graph with 15 nearest-neighbours...
# Setting random seeds...
# Generating an ensemble with 200 partitions...
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Elapsed time:  1.00 seconds
# Building the graph... done!
# Clustering graph with 20 nearest-neighbours...
# Setting random seeds...
# Generating an ensemble with 200 partitions...
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Elapsed time:  1.00 seconds
# Building the graph... done!
# Clustering graph with 25 nearest-neighbours...
# Setting random seeds...
# Generating an ensemble with 200 partitions...
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Elapsed time:  1.00 seconds
# Building the graph... done!
# Clustering graph with 30 nearest-neighbours...
# Setting random seeds...
# Generating an ensemble with 200 partitions...
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Elapsed time:  1.00 seconds
# Building the graph... done!
# Clustering graph with 60 nearest-neighbours...
# Setting random seeds...
# Generating an ensemble with 200 partitions...
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Elapsed time:  2.00 seconds
# Clustering the consensus partition...
# Setting random seeds...
# Using co-occurrence matrix to do consensus clustering...
# Building the graph... done!
# Setting random seeds...
# Generating an ensemble with 100 partitions...
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Average pairwise AMI across 100 partitions is 1.0
# Clustering with 145 nodes and 3 clusters.
# Elapsed time: 15 seconds
# ==============
# Partitioning cluster 8...
# Building the graph... done!
# Clustering graph with 15 nearest-neighbours...
# Setting random seeds...
# Generating an ensemble with 200 partitions...
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Elapsed time:  1.00 seconds
# Building the graph... done!
# Clustering graph with 20 nearest-neighbours...
# Setting random seeds...
# Generating an ensemble with 200 partitions...
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Elapsed time:  1.00 seconds
# Building the graph... done!
# Clustering graph with 25 nearest-neighbours...
# Setting random seeds...
# Generating an ensemble with 200 partitions...
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Elapsed time:  1.00 seconds
# Building the graph... done!
# Clustering graph with 30 nearest-neighbours...
# Setting random seeds...
# Generating an ensemble with 200 partitions...
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Elapsed time:  1.00 seconds
# Building the graph... done!
# Clustering graph with 60 nearest-neighbours...
# Setting random seeds...
# Generating an ensemble with 200 partitions...
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Elapsed time:  2.00 seconds
# Clustering the consensus partition...
# Setting random seeds...
# Using co-occurrence matrix to do consensus clustering...
# Building the graph... done!
# Setting random seeds...
# Generating an ensemble with 100 partitions...
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Average pairwise AMI across 100 partitions is 0.9852
# Clustering with 129 nodes and 3 clusters.
# Elapsed time: 17 seconds
# ==============
# Partitioning cluster 9...
# Building the graph... done!
# Clustering graph with 15 nearest-neighbours...
# Setting random seeds...
# Generating an ensemble with 200 partitions...
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Elapsed time:  1.00 seconds
# Building the graph... done!
# Clustering graph with 20 nearest-neighbours...
# Setting random seeds...
# Generating an ensemble with 200 partitions...
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Elapsed time:  1.00 seconds
# Building the graph... done!
# Clustering graph with 25 nearest-neighbours...
# Setting random seeds...
# Generating an ensemble with 200 partitions...
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Elapsed time:  1.00 seconds
# Building the graph... done!
# Clustering graph with 30 nearest-neighbours...
# Setting random seeds...
# Generating an ensemble with 200 partitions...
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Elapsed time:  1.00 seconds
# Building the graph... done!
# Clustering graph with 60 nearest-neighbours...
# Setting random seeds...
# Generating an ensemble with 200 partitions...
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Elapsed time:  2.00 seconds
# Clustering the consensus partition...
# Setting random seeds...
# Using co-occurrence matrix to do consensus clustering...
# Building the graph... done!
# Setting random seeds...
# Generating an ensemble with 100 partitions...
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Average pairwise AMI across 100 partitions is 1.0
# Clustering with 124 nodes and 3 clusters.
# Elapsed time: 16 seconds
# ==============
# Partitioning cluster 10...
# Building the graph... done!
# Clustering graph with 15 nearest-neighbours...
# Setting random seeds...
# Generating an ensemble with 200 partitions...
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Elapsed time:  1.00 seconds
# Building the graph... done!
# Clustering graph with 20 nearest-neighbours...
# Setting random seeds...
# Generating an ensemble with 200 partitions...
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Elapsed time:  1.00 seconds
# Building the graph... done!
# Clustering graph with 25 nearest-neighbours...
# Setting random seeds...
# Generating an ensemble with 200 partitions...
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Elapsed time:  1.00 seconds
# Building the graph... done!
# Clustering graph with 30 nearest-neighbours...
# Setting random seeds...
# Generating an ensemble with 200 partitions...
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Elapsed time:  1.00 seconds
# Building the graph... done!
# Clustering graph with 60 nearest-neighbours...
# Setting random seeds...
# Generating an ensemble with 200 partitions...
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Elapsed time:  1.00 seconds
# Clustering the consensus partition...
# Setting random seeds...
# Using co-occurrence matrix to do consensus clustering...
# Building the graph... done!
# Setting random seeds...
# Generating an ensemble with 100 partitions...
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Average pairwise AMI across 100 partitions is 0.8609
# Clustering with 89 nodes and 4 clusters.
# Elapsed time: 14 seconds
# ==============
# Partitioning cluster 11...
# Building the graph... done!
# Clustering graph with 15 nearest-neighbours...
# Setting random seeds...
# Generating an ensemble with 200 partitions...
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Elapsed time:  0.00 seconds
# Building the graph... done!
# Clustering graph with 20 nearest-neighbours...
# Setting random seeds...
# Generating an ensemble with 200 partitions...
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Elapsed time:  1.00 seconds
# Building the graph... done!
# Clustering graph with 25 nearest-neighbours...
# Setting random seeds...
# Generating an ensemble with 200 partitions...
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Elapsed time:  1.00 seconds
# Building the graph... done!
# Clustering graph with 30 nearest-neighbours...
# Setting random seeds...
# Generating an ensemble with 200 partitions...
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Elapsed time:  1.00 seconds
# Building the graph... done!
# Clustering graph with 60 nearest-neighbours...
# Setting random seeds...
# Generating an ensemble with 200 partitions...
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Elapsed time:  1.00 seconds
# Clustering the consensus partition...
# Setting random seeds...
# Using co-occurrence matrix to do consensus clustering...
# Building the graph... done!
# Setting random seeds...
# Generating an ensemble with 100 partitions...
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Average pairwise AMI across 100 partitions is 1.0
# Clustering with 87 nodes and 3 clusters.
# Elapsed time: 16 seconds
# ==============
# Partitioning cluster 12...
# Building the graph... done!
# Clustering graph with 15 nearest-neighbours...
# Setting random seeds...
# Generating an ensemble with 200 partitions...
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Elapsed time:  0.00 seconds
# Building the graph... done!
# Clustering graph with 20 nearest-neighbours...
# Setting random seeds...
# Generating an ensemble with 200 partitions...
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Elapsed time:  1.00 seconds
# Building the graph... done!
# Clustering graph with 25 nearest-neighbours...
# Setting random seeds...
# Generating an ensemble with 200 partitions...
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Elapsed time:  1.00 seconds
# Building the graph... done!
# Clustering graph with 30 nearest-neighbours...
# Setting random seeds...
# Generating an ensemble with 200 partitions...
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Elapsed time:  1.00 seconds
# Building the graph... done!
# Clustering graph with 60 nearest-neighbours...
# Setting random seeds...
# Generating an ensemble with 200 partitions...
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Elapsed time:  1.00 seconds
# Clustering the consensus partition...
# Setting random seeds...
# Using co-occurrence matrix to do consensus clustering...
# Building the graph... done!
# Setting random seeds...
# Generating an ensemble with 100 partitions...
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Average pairwise AMI across 100 partitions is 0.9968
# Clustering with 74 nodes and 3 clusters.
# Elapsed time: 13 seconds
# ==============
# Partitioning cluster 13...
# Building the graph... done!
# Clustering graph with 15 nearest-neighbours...
# Setting random seeds...
# Generating an ensemble with 200 partitions...
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Elapsed time:  0.00 seconds
# Building the graph... done!
# Clustering graph with 20 nearest-neighbours...
# Setting random seeds...
# Generating an ensemble with 200 partitions...
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Elapsed time:  1.00 seconds
# Building the graph... done!
# Clustering graph with 25 nearest-neighbours...
# Setting random seeds...
# Generating an ensemble with 200 partitions...
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Elapsed time:  1.00 seconds
# Building the graph... done!
# Clustering graph with 30 nearest-neighbours...
# Setting random seeds...
# Generating an ensemble with 200 partitions...
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Elapsed time:  1.00 seconds
# Building the graph... done!
# Clustering graph with 60 nearest-neighbours...
# Setting random seeds...
# Generating an ensemble with 200 partitions...
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Elapsed time:  1.00 seconds
# Clustering the consensus partition...
# Setting random seeds...
# Using co-occurrence matrix to do consensus clustering...
# Building the graph... done!
# Setting random seeds...
# Generating an ensemble with 100 partitions...
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Average pairwise AMI across 100 partitions is 1.0
# Clustering with 74 nodes and 3 clusters.
# Elapsed time: 13 seconds

# %%
# Adjust the clustering labels and save
partition_2 = cluster_utils.collect_subclusters(1, fpath, session_name, n_total = n_occ)
partition_2.cluster = partition_2.cluster-1
partition_2.to_csv(fpath + 'ESCO_occ_v1_clusters_Level2.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-15-4e2bae43635d> in <module>
#       1 # Adjust the clustering labels and save
# ----> 2 partition_2 = cluster_utils.collect_subclusters(1, fpath, session_name, n_total = n_occ)
#       3 partition_2.cluster = partition_2.cluster-1
#       4 partition_2.to_csv(fpath + 'ESCO_occ_v1_clusters_Level2.csv', index=False)
#
# ~/Documents/mapping-career-causeways/mapping_career_causeways/cluster_utils.py in collect_subclusters(l, fpath, session_name, n_total)
#     849     # Take care of nodes that have not been included in the subclusters (assign all to one, 0-th cluster)
#     850     # (e.g., these will be the central nodes in the case of Level-1 TSC clustering)
# --> 851     if (len(data) != n_total) & (n_total is not None):
#     852         all_data.cluster = all_data.cluster + 1
#     853         partition = pd.DataFrame(data={'id':list(range(n_total))})
#
# UnboundLocalError: local variable 'data' referenced before assignment

# %%
cluster_utils.ConsensusClustering.describe_partition(partition_2.cluster.values);
# Out:
# Clustering with 2942 nodes and 54 clusters.

# %% [markdown]
# # 3. Combine the partitions from both steps

# %%
partition_1 = pd.read_csv(fpath + session_name + '_clusters_Level1.csv')
partition_2 = pd.read_csv(fpath + session_name + '_clusters_Level2.csv')

# Create a dataframe with all three partitions
partitions = partition_1.merge(partition_2, on='id')
partitions = partitions.rename(columns={'cluster_x': 'level_1', 'cluster_y': 'level_2'})

# Relabel Level 2 clusters to match the ordering of Level 1 clusters
partitions = partitions.sort_values(['level_1','level_2'])
level_2_labels = partitions.drop_duplicates('level_2').level_2.to_list()
level_2_new_labels = list(range(len(level_2_labels)))
relabel_dict = dict(zip(level_2_labels, level_2_new_labels))
partitions.level_2 = partitions.level_2.apply(lambda x: relabel_dict[x])
partitions = partitions.sort_values('id')

partitions.sort_values(['level_1','level_2'])
# Out:
#         id  level_1  level_2
# 2        2        0        0
# 51      51        0        0
# 83      83        0        0
# 93      93        0        0
# 113    113        0        0
# ...    ...      ...      ...
# 604    604       13       53
# 1281  1281       13       53
# 1917  1917       13       53
# 2850  2850       13       53
# 2918  2918       13       53
#
# [2942 rows x 3 columns]

# %%
# Final dataframe with occupation clusters
occ_cluster = load_data.Data().occupation_hierarchy.merge(partitions, on='id')
occ_cluster = occ_cluster[['id', 'concept_uri', 'preferred_label',
                           'isco_level_4',
                           'level_1', 'level_2']]

# %%
len(occ_cluster)
# Out:
# 2942

# %% [markdown]
# # 4. Profile the clusters

# %%
occ_cluster.head(2)
# Out:
#    id                                        concept_uri  \
# 0   0  http://data.europa.eu/esco/occupation/00030d09...
# 1   1  http://data.europa.eu/esco/occupation/000e93a3...
#
#                   preferred_label  isco_level_4   onet_code  \
# 0              technical director          2166  27-1011.00
# 1  metal drawing machine operator          8121  51-4021.00
#
#                                           onet_title  level_1  level_2
# 0                                      art directors        5       25
# 1  extruding and drawing machine setters, operato...        3       16

# %%
occ_df = occupations.copy()
occ_df['onet_title'] = occ_risk['onet_title']
occ_df.loc[occ_df.onet_title.isnull(), 'onet_title'] = 'military occupation'

# %%
# Clusters keywords
keywords_level_1, keywords_level_1_ = profile_clusters_utils.tfidf_keywords(partitions.level_1.values,
                                                                            occ_df, 'preferred_label', [])
keywords_level_2, keywords_level_2_ = profile_clusters_utils.tfidf_keywords(partitions.level_2.values,
                                                                            occ_df, 'preferred_label', [])

# %%
# keywords_level_2

# %%
clusters_level_1 = partitions.copy().drop_duplicates('level_1').sort_values('level_1')
clusters_level_1 = clusters_level_1.drop(['level_2','id'], axis=1)
clusters_level_1['keywords'] = keywords_level_1
clusters_level_1 = clusters_level_1.reset_index(drop=True)

clusters_level_2 = partitions.copy().drop_duplicates(['level_1','level_2']).sort_values(['level_2'])
clusters_level_2 = clusters_level_2.drop(['id'], axis=1)
clusters_level_2['keywords'] = keywords_level_2
clusters_level_2 = clusters_level_2.reset_index(drop=True)

# %%
clusters_level_1
# Out:
#     level_1                                           keywords
# 0         0  technician, operator, inspector, assembler, mi...
# 1         1  manager, officer, policy, policy officer, anal...
# 2         2  shop, shop manager, seller, specialised seller...
# 3         3  operator, machine operator, machine, maker, pr...
# 4         4  engineer, technician, drafter, engineering, en...
# 5         5  artist, director, editor, designer, painter, j...
# 6         6  teacher, school, lecturer, secondary school, s...
# 7         7  leather, leather good, textile, footwear, oper...
# 8         8  operator, food, operator food, machine operato...
# 9         9  import export, export, import, export manager,...
# 10       10  therapist, assistant, clinical, pharmacist, pr...
# 11       11  ict, developer, data, system, ict system, deve...
# 12       12  aquaculture, animal, breeder, technician, work...
# 13       13  social, worker, social worker, care, support w...

# %%
clusters_level_2
# Out:
#     level_1  level_2                                           keywords
# 0         0        0  assembler, technician, inspector, engineering ...
# 1         0        1  supervisor, construction, installer, operator,...
# 2         0        2  technician, repair technician, repair, operato...
# 3         0        3  officer, driver, guard, pilot, aviation, airpo...
# 4         0        4  environmental, inspector, worker, waste, prote...
# 5         0        5  mine, engineer, manager mine, operator, mining...
# 6         1        6  manager, supervisor, assembly supervisor, asse...
# 7         1        7  financial, insurance, analyst, manager, broker...
# 8         1        8  assistant, clerk, officer, court, administrati...
# 9         1        9  manager, business, product manager, officer, p...
# 10        1       10  policy officer, policy, officer, affair, consu...
# 11        2       11  attendant, cleaner, chef, restaurant, head, ro...
# 12        2       12  representative, sale, sale representative, ser...
# 13        2       13  shop manager, shop, manager, equipment shop, e...
# 14        2       14  specialised seller, seller, specialised, equip...
# 15        2       15  merchant, wholesale merchant, wholesale, produ...
# 16        3       16  operator, machine operator, machine, metal, op...
# 17        3       17  operator, machine, machine operator, kiln, mix...
# 18        3       18  maker, musical instrument, instrument maker, m...
# 19        3       19  operator, paper, machine operator, machine, pr...
# 20        4       20  technician, scientist, chemist, research, surv...
# 21        4       21  engineer, energy, engineer energy, energy engi...
# 22        4       22  engineer, drafter, engineering, engineering te...
# 23        5       23  designer, technician, stage, prop, set, sound,...
# 24        5       24  editor, journalist, music, news, interpreter, ...
# 25        5       25  director, motion, video motion, animator, moti...
# 26        5       26  artist, stand, performer, titeur, model, fashi...
# 27        5       27  artist, painter, glass, artist glass, designer...
# 28        6       28  teacher, instructor, vocational teacher, vocat...
# 29        6       29  teacher, school, secondary, secondary school, ...
# 30        6       30  lecturer, science lecturer, science, instructo...
# 31        6       31  head, head teacher, teacher, school, school he...
# 32        7       32  leather good, leather, footwear, good, operato...
# 33        7       33  textile, textile technician, machine, machine ...
# 34        7       34  clothing, operator clothing, apparel, machinis...
# 35        8       35  operator, slaughterer, butcher, fish, machine ...
# 36        8       36  operator, mill operator, mill, machine operato...
# 37        8       37  food, food production, master, coffee, product...
# 38        9       38  distribution manager, distribution, manager, p...
# 39        9       39  export specialist, import, import export, expo...
# 40        9       40  export manager, export, import export, import,...
# 41       10       41  therapist, psychologist, practitioner, special...
# 42       10       42  radiographer, technician, dental, radiographer...
# 43       10       43  therapist, pharmacist, occupational, tradition...
# 44       10       44  medical, medical record, assistant, record, ph...
# 45       11       45  ict, ict security, ict system, security, archi...
# 46       11       46  developer, ict, tester, developer ict, softwar...
# 47       11       47  data, database, designer data, designer, entry...
# 48       12       48  animal, therapist animal, veterinarian, veteri...
# 49       12       49  breeder, cattle, poultry, livestock, dog, equi...
# 50       12       50  aquaculture, technician aquaculture, aquacultu...
# 51       13       51  social, social worker, worker, social work, wo...
# 52       13       52  worker, care, care worker, counsellor, residen...
# 53       13       53  fortune, dating service, astrologer fortune, c...

# %% [markdown]
# # 5. Export the final partitions

# %%
occ_cluster.to_csv(data_folder + f'interim/raw_clustering/partitions_{session_name}.csv', index=False)
clusters_level_1.to_csv(data_folder + f'interim/raw_clustering/partitions_{session_name}_LEVEL1.csv', index=False)
clusters_level_2.to_csv(data_folder + f'interim/raw_clustering/partitions_{session_name}_LEVEL2.csv', index=False)

# %% [markdown]
# # 6. Deeper manual profiling and curation
#
# After obtaining two levels of occupational clusters, we performed a manual review of the results to label them and to make adjustments to the cluster membership of nodes if necessary.

# %% [markdown]
# ## 6.1 Pre-requisites

# %%
import seaborn as sns
from matplotlib import pyplot as plt
import plotly.express as px

# Coordinates for the visualisation
X_ = np.load(data_folder + 'interim/ESCO_occ_UMAP_2D_embedding.npy')

# Colors
color_pal = ['#DCDCDC', '#e6194b', '#3cb44b', '#ffe119', '#4363d8', '#f58231',
             '#911eb4', '#46f0f0', '#f032e6', '#bcf60c', '#fabebe',
             '#008080', '#e6beff', '#9a6324', '#808080', '#800000',
             '#aaffc3', '#000000', '#ffd8b1', '#808000', '#000075']

# %%
# Cluster data
occ_clust = pd.read_csv(data_folder + 'processed/clusters/ESCO_occupation_clusters_v1.csv')
clusters_level_1 = pd.read_csv(data_folder + 'processed/clusters/ESCO_occupation_clusters_v1_LEVEL1_manual.csv')
clusters_level_2 = pd.read_csv(data_folder + 'processed/clusters/ESCO_occupation_clusters_v1_LEVEL2_manual.csv')

# %%
clusters_level_1
# Out:
#     level_1                                           keywords  \
# 0         0  technician, operator, inspector, assembler, mi...
# 1         1  manager, officer, policy, policy officer, anal...
# 2         2  shop, shop manager, seller, specialised seller...
# 3         3  operator, machine operator, machine, maker, pr...
# 4         4  engineer, technician, drafter, engineering, en...
# 5         5  artist, director, editor, designer, painter, j...
# 6         6  teacher, school, lecturer, secondary school, s...
# 7         7  leather, leather good, textile, footwear, oper...
# 8         8  operator, food, operator food, machine operato...
# 9         9  import export, export, import, export manager,...
# 10       10  therapist, assistant, clinical, pharmacist, pr...
# 11       11  ict, developer, data, system, ict system, deve...
# 12       12  aquaculture, animal, breeder, technician, work...
# 13       13  social, worker, social worker, care, support w...
#
#                                       keywords_manual
# 0   technicians, construction, transport & securit...
# 1                     business administration workers
# 2                            sales & services workers
# 3                               manufacturing workers
# 4                             engineers & researchers
# 5                                arts & media workers
# 6                                   education workers
# 7   textile, clothing, leather & footwear manufact...
# 8                   food & tobacco production workers
# 9                                   logistics workers
# 10                                 healthcare workers
# 11                                        ict workers
# 12                    animal care & husbandry workers
# 13                                     social workers

# %%
def get_cluster_counts(level, clusters_level):
    level_counts = occ_clust.groupby(level).count()
    level_counts[level] = level_counts.index.to_list()
    level_counts = level_counts.rename(columns={'id': 'counts'}).reset_index(drop=True)
    clusters_level = clusters_level.merge(level_counts[[level, 'counts']], on=level, how='left')
    return clusters_level

# %%
# Number of skills per cluster
clusters_level_1 = get_cluster_counts('level_1', clusters_level_1)
clusters_level_2 = get_cluster_counts('level_2', clusters_level_2)

# %%
# Viz dataframe
def highlight_cluster(cluster_id, level, clusters_level):
    
    occ_viz = occ_clust.copy()
    occ_viz = occ_viz.merge(occ_risk[['id','risk_cat_label']], on='id', how='left')
    occ_viz = occ_viz.merge(clusters_level[[level,'keywords_manual']], on=level, how='left')

    occ_viz['x'] = X_[:,0]
    occ_viz['y'] = X_[:,1]

    # Select a label to highlight
    lab = 'Very high risk'
    occ_viz['color'] = 'other'
    occ_viz.loc[((occ_viz[level]==cluster_id)&(occ_viz.risk_cat_label==lab)),'color'] = 'very high risk'
    occ_viz.loc[((occ_viz[level]==cluster_id)&(occ_viz.risk_cat_label!=lab)),'color'] = 'NOT very high risk'

    color_discrete_map={
        "other": color_pal[0],
        "very high risk": 'red',
        "NOT very high risk": "blue"}

    fig = px.scatter(occ_viz, x='x', y='y',
                     hover_data=['id','preferred_label', 'onet_title', 
                                 'risk_cat_label', 'level_1', 'level_2', 'keywords_manual'],
                     color='color',
                     color_discrete_map = color_discrete_map,
                     width=1000, height=500, opacity=0.66)
    fig.update_traces(textposition='top center', textfont_size=10)
    fig.update_layout(plot_bgcolor='rgb(255,255,255)', title=clusters_level.loc[cluster_id].keywords_manual)
#     fig.update_xaxes(range=[-10,10])
    # fig.update_yaxes(range=[-2, 22])
    fig.show()

# %%
# Save the edits here
curated_clusters = occ_clust[['id', 'level_1', 'level_2']].copy()

# %% [markdown]
# ## 6.2 CHECK: Majority of neighbors

# %%
def check_majority_neighbors(j_id, k = 10, level='level_2'):
    # Find closest neighbors
    df = find_closest(j_id, W_combined, occ_clust).iloc[1:k].groupby(level).count()
    # Clusters
    clusts = df.index.to_list()
    # Counts
    counts = df.id.values
    # Proportion of neighbors in each cluster
    vote = counts / counts.sum()
    # Majority cluster
    majority_clust = clusts[np.argsort(vote)[-1]]
    majority_vote = max(vote)
    is_same = (majority_clust == occ_clust.loc[j_id][level])
    
    # Assigned cluster
    own_clust_index = np.where(np.array(clusts)==occ_clust.loc[j_id][level])[0]
    if len(own_clust_index)!=0:
        own_clust_vote = vote[own_clust_index[0]]
    else:
        own_clust_vote=0
        
    return is_same, majority_vote, majority_clust, own_clust_vote


def get_majority_neighbor_df(k = 10, level='level_2', clusters_level=clusters_level_2):
    
    majority_neighbors_df = pd.DataFrame(data={
        'id':[],
        'is_same':[],
        'majority_vote':[],
        'majority_clust':[],
        'own_clust_vote': []})

    for i, row in occ_clust.iterrows():
        is_same, majority_vote, majority_clust, own_clust_vote = check_majority_neighbors(row.id, k, level)
        majority_neighbors_df = majority_neighbors_df.append({
            'id': row.id,
            'is_same': is_same,
            'majority_vote': majority_vote,
            'majority_clust': majority_clust,
            'own_clust_vote': own_clust_vote
        }, ignore_index=True)
    
    # Add titles, cluster labels and order columns
    majority_neighbors_df = majority_neighbors_df.merge(occ_clust[[level,'id', 'preferred_label']], on='id', how='left')
    majority_neighbors_df.rename(columns={level:'own_clust'}, inplace=True)
    majority_neighbors_df = majority_neighbors_df.merge(clusters_level[[level, 'keywords_manual']],
                              left_on='own_clust', right_on=level, how='left')
    majority_neighbors_df = majority_neighbors_df.merge(clusters_level[[level, 'keywords_manual']],
                              left_on='majority_clust', right_on=level, how='left')
    majority_neighbors_df.rename(columns={'keywords_manual_x': 'own_label'}, inplace=True)
    majority_neighbors_df.rename(columns={'keywords_manual_y': 'majority_label'}, inplace=True)
    majority_neighbors_df.drop([level+'_x',level+'_y'], axis=1, inplace=True)
        
    return majority_neighbors_df

# %%
majority_neighbors = get_majority_neighbor_df(15, 'level_2', clusters_level_2)

# %%
majority_neighbors.groupby('is_same').count()
# Out:
#            id  majority_vote  majority_clust  own_clust_vote  own_clust  \
# is_same
# 0.0       231            231             231             231        231
# 1.0      2711           2711            2711            2711       2711
#
#          preferred_label  own_label  majority_label
# is_same
# 0.0                  231        231             231
# 1.0                 2711       2711            2711

# %%
# Ratio
majority_neighbors['ratio'] = majority_neighbors['majority_vote']/majority_neighbors_level_1['own_clust_vote']

# %%
majority_neighbors = majority_neighbors[['id','preferred_label','is_same','own_clust_vote','majority_vote',
                                         'own_clust','majority_clust',
                                         'own_label','majority_label', 'ratio']]

# %% [markdown]
# Manually assess occupations that are not in the same cluster as the majority of their neighbours...

# %%
# Interesting one...
art_preservation_cluster = [
    569,
    121,
    1153,
    1966,
    1712,
    1787,
    1402
]

# %%
# find_closest(43, W_combined, occ_clust).head(25)[['preferred_label','level_1','level_2']]
# Out:
# 'Aquaculture mooring managers carry out and supervise the mooring of cages in stable stations, drifting cages or even self-propelled and semi-submerged cages. They safely operate and moor a variety of different types of large-scale cages, manage conditions such as currents, wave climate and seabed profile, in open or semi-open water areas.'

# %%
majority_neighbors.sort_values('ratio', ascending=False).loc[820]
# Out:
# id                                   820
# preferred_label     ICT capacity planner
# is_same                                0
# own_clust_vote                  0.214286
# majority_vote                   0.285714
# own_clust                             38
# majority_clust                        45
# own_label          distribution managers
# majority_label              ict managers
# ratio                            1.33333
# Name: 820, dtype: object

# %% [markdown]
# ## 6.3 CHECK: Qualitative check

# %%
cluster_id = 21
print(f'{clusters_level_2.loc[cluster_id].counts} occupations in this cluster.')
highlight_cluster(cluster_id, 'level_2', clusters_level_2)
# Out:
# 85 occupations in this cluster.
# <div>
#
#
#             <div id="54b0c7b7-9e9c-479e-90c2-6f4bbc18aba9" class="plotly-graph-div" style="height:500px; width:1000px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("54b0c7b7-9e9c-479e-90c2-6f4bbc18aba9")) {
#                     Plotly.newPlot(
#                         '54b0c7b7-9e9c-479e-90c2-6f4bbc18aba9',
#                         [{"customdata": [[0, "technical director", "art directors", "Hidden protection", 5, 25, "creative managers & graphic designers"], [1, "metal drawing machine operator", "extruding and drawing machine setters, operators, and tenders, metal and plastic", "Very low risk", 3, 16, "metal workers & machine operators"], [2, "precision device inspector", "inspectors, testers, sorters, samplers, and weighers", "Hidden protection", 0, 0, "engineering technicians"], [3, "air traffic safety technician", "electronics engineering technicians", "Hidden risk", 0, 3, "transport & security workers"], [4, "hospitality revenue manager", "market research analysts and marketing specialists", "Hidden protection", 1, 9, "business managers"], [5, "medical laboratory assistant", "medical and clinical laboratory technicians", "Hidden protection", 4, 20, "researchers & science technicians"], [6, "asphalt laboratory technician", "chemical engineers", "Low risk", 0, 1, "construction workers & supervisors"], [7, "primary school teaching assistant", "teacher assistants", "Hidden risk", 6, 29, "teachers & childcare workers"], [8, "physiotherapist", "physical therapists", "Hidden risk", 10, 41, "doctors & specialist therapists"], [9, "performing arts theatre instructor", "history teachers, postsecondary", "Hidden risk", 6, 30, "lecturers"], [10, "hydrogenation machine operator", "separating, filtering, clarifying, precipitating, and still machine setters, operators, and tenders", "Low risk", 8, 36, "food production operators"], [11, "pasta operator", "food batchmakers", "Hidden protection", 8, 35, "food production workers"], [12, "tobacco shop manager", "first-line supervisors of retail sales workers", "Hidden risk", 2, 13, "shop & services managers"], [13, "rental service representative in machinery, equipment and tangible goods", "counter and rental clerks", "Very high risk", 2, 12, "customer representatives"], [14, "mine surveyor", "surveyors", "Hidden risk", 0, 5, "mining engineers & technicians"], [15, "food safety specialist", "occupational health and safety specialists", "Low risk", 8, 37, "food production specialists"], [16, "land-based machinery technician", "farm equipment mechanics and service technicians", "Low risk", 0, 2, "industrial technicians, mechanics & repairers"], [17, "bus driver", "bus drivers, transit and intercity", "Hidden risk", 0, 3, "transport & security workers"], [18, "import export manager in meat and meat products", "logistics managers", "Very high risk", 9, 40, "import export managers"], [19, "housing policy officer", "management analysts", "Hidden risk", 1, 10, "public officials"], [20, "head chef", "chefs and head cooks", "Hidden risk", 2, 11, "food, cleaning & customer services workers"], [21, "nonwoven filament machine operator", "extruding and drawing machine setters, operators, and tenders, metal and plastic", "Very low risk", 7, 33, "textile workers"], [22, "head of higher education institutions", "education administrators, elementary and secondary school", "Very high risk", 6, 31, "education administrators"], [23, "insulation supervisor", "first-line supervisors of construction trades and extraction workers", "Low risk", 0, 1, "construction workers & supervisors"], [24, "dismantling engineer", "industrial engineering technicians", "High risk", 4, 22, "mechanical engineers, designers & drafters"], [25, "insurance claims handler", "claims examiners, property and casualty insurance", "Hidden risk", 1, 7, "accounting & financial services workers"], [26, "clothing development manager", "natural sciences managers", "High risk", 7, 34, "clothing manufacturing workers"], [27, "nitroglycerin separator operator", "chemical equipment operators and tenders", "High risk", 3, 17, "chemical manufacturing workers"], [29, "legal guardian", "social and human service assistants", "Very high risk", 13, 52, "care workers & counsellors"], [30, "weaver", "textile knitting and weaving machine setters, operators, and ten ...

# %%
for i, row in occ_clust[occ_clust.level_2==cluster_id].sort_values('preferred_label').iterrows():
    print(f'{row.preferred_label} ({row.id})')
# Out:
# artistic painter (667)
# cartoonist (2739)
# ceramic painter (42)
# ceramicist (2733)
# community artist (943)
# conceptual artist (1785)
# decorative painter (781)
# digital artist (2511)
# drawing artist (796)
# furniture designer (2219)
# glass artist (2112)
# glass painter (1299)
# glass-blower (1204)
# interior designer (1393)
# performance artist (1969)
# porcelain painter (2566)
# sculptor (1763)
# sign maker (1911)
# street artist (108)
# video artist (1484)
# wood painter (1780)

# %%
occupations.loc[2598].description
# Out:
# 'Energy consultants advise clients on the advantages and disadvantages of different energy sources. They help clients to understand energy tariffs and try to reduce their energy consumption and carbon footprint by using energy efficient products and methods.'

# %%
find_closest(2598, W_combined, occ_clust).head(25)[['preferred_label','level_1','level_2', 'similarity']]
# Out:
#                                         preferred_label  level_1  level_2  \
# 2598                                  energy consultant        0        1
# 2914                      solar energy sales consultant        2       12
# 2932              renewable energy sales representative        2       12
# 124                            domestic energy assessor        2       14
# 215                         renewable energy consultant        2       12
# 908                    electricity sales representative        2       12
# 2412                                     energy analyst        4       21
# 430                         energy conservation officer        4       21
# 2364                                    energy assessor        4       21
# 1959                                 specialist dentist       10       41
# 452                       leather goods manual operator        7       32
# 355                 leather goods hand cutting operator        7       32
# 2732                                  fishing net maker        0        4
# 2388                     technical sales representative        2       12
# 250                     commercial sales representative        2       12
# 874   technical sales representative in hardware, pl...        2       12
# 549   technical sales representative in agricultural...        2       12
# 2461  technical sales representative in the textile ...        2       12
# 2263  technical sales representative in chemical pro...        2       12
# 2679  technical sales representative in office machi...        2       12
# 993   technical sales representative in mining and c...        2       12
# 181                           renewable energy engineer        4       21
# 2162  technical sales representative in machinery an...        2       12
# 390                             energy systems engineer        4       21
# 2027                       medical sales representative        2       12
#
#       similarity
# 2598    0.999625
# 2914    0.499103
# 2932    0.485631
# 124     0.481013
# 215     0.476293
# 908     0.467958
# 2412    0.439260
# 430     0.438406
# 2364    0.429292
# 1959    0.371259
# 452     0.365604
# 355     0.365600
# 2732    0.344922
# 2388    0.326120
# 250     0.323542
# 874     0.323016
# 549     0.323012
# 2461    0.323012
# 2263    0.323012
# 2679    0.323012
# 993     0.323012
# 181     0.321222
# 2162    0.314905
# 390     0.314139
# 2027    0.313189

# %% [markdown]
# ## 6.4 CHECK: Manual curation

# %%
switch_labels = {
    131: 33, # textile machine operator to textiles
    1982: 18, # taxidermist to craftsmen
    847: 23, # rental technician to technicians
    1948: 49, # game keeper to animal husbandry
    2497: 50, # aquaculture
    1179: 48,
    2835: 48,
    1219: 48,
    1161: 47,
    613: 45, # picture archiving sys admin
    1531: 41, # speech & language to the advanced
    2331: 41,
    820: 45,
    1405: 53, # graphologist
    1446: 36, # bunch of operators re-assigned to operator cluster
    11: 36,
    2089: 36,
    2651: 36,
    1584: 36,
    2278: 36,
    1345: 36,
    2741: 36,
    507: 36,
    1446: 36,
    1747: 36,
    200: 36,
    1206: 36,
    1343: 36,
    1123: 36,
    2185: 36,
    1266: 11, # aircraft groomer should go to cleaners 
    2134: 11, # airline food service worker should go to food services
    744: 3, # warehouse workers & movers to transport & security
    2754: 3,
    2144: 3,
    2368: 3,
    2424: 3,
    2258: 3,
    2825: 3,
    1884: 28, # trainers to instructors
    145: 28,
    2650: 20, # conservation scientists to research
    690: 43, # personal trainer to physical therapists
    1144: 42, # pharmacists to technicians & scientists
    1486: 42,
    1703: 42,
    2645: 11, # amusement and recreation attendant to services
    1969: 26, # performance artist
    1337: 23, # camera operator to media engineers
    852: 47, ## Language engineer to data? Interesting that it is together with other engineers 
    330: 20, # chemical application specialist to science technician
    435: 2, # Greaser to mechanics
    1673: 16, #
    2359: 28, # fitness instructor to instructors
    778: 11, # body artist 
    904: 3, ## airport CEO to transport
    2639: 10,
    1413: 43, ## weight loss consultant
    913: 3, ## intelligence officer
    1428: 3, ## private detective
    1850: 2, # vending machine operators
    687: 11,
    693: 6,
    611: 1, # construction
    2768: 1, # construction
    1911: 23, # art tech
    2219: 23, # art tech
    569: 18, # book and art restorers to craftsmen
    121: 18,
    1153: 23,
    1966: 20, # museum scientist
    1712: 25,
    1787: 25,
    1402: 23,
    2598: 12,
    889: 51 # social worker to social workers
}

# %%
len(switch_labels.keys())
# Out:
# 75

# %%
df = occ_clust.loc[list(switch_labels.keys())].copy()
df['level_2'] = list(switch_labels.values())
df = df.merge(clusters_level_2[['level_2', 'keywords_manual']], how='left', on='level_2')
df = df.sort_values(['level_2'])
df[['id','preferred_label','level_2','keywords_manual']].iloc[30:]
# Out:
#       id                                    preferred_label  level_2  \
# 68  1153                                        art handler       23
# 72  1402                                        conservator       23
# 2    847                      performance rental technician       23
# 65  2219                                 furniture designer       23
# 64  1911                                         sign maker       23
# 70  1712                               exhibition registrar       25
# 71  1787                                 collection manager       25
# 46  1969                                 performance artist       26
# 52  2359                                 fitness instructor       28
# 39   145                                  corporate trainer       28
# 38  1884                                        ICT trainer       28
# 0    131            textile pattern making machine operator       33
# 17  2651                           food production operator       36
# 15    11                                     pasta operator       36
# 19  2278                          fish preparation operator       36
# 20  1345                              fish canning operator       36
# 21  2741                  cigarette making machine operator       36
# 22   507                                  chilling operator       36
# 23  1747                 canning and bottling line operator       36
# 18  1584                           fish production operator       36
# 24   200                             candy machine operator       36
# 14  1446                   capsule filling machine operator       36
# 26  1343                                 blanching operator       36
# 27  1123                                    baking operator       36
# 28  2185                               animal feed operator       36
# 25  1206                                   blender operator       36
# 16  2089             packaging and filling machine operator       36
# 11  2331                                        audiologist       41
# 10  1531                      speech and language therapist       41
# 42  1144                                hospital pharmacist       42
# 44  1703                              specialist pharmacist       42
# 43  1486                                         pharmacist       42
# 56  1413                             weight loss consultant       43
# 41   690                                    sport therapist       43
# 12   820                               ICT capacity planner       45
# 9    613  picture archiving and communication systems ad...       45
# 48   852                                  language engineer       47
# 8   1161                                          librarian       47
# 7   1219                               guide dog instructor       48
# 6   2835                                          zookeeper       48
# 5   1179                                 zoo section leader       48
# 3   1948                                        game keeper       49
# 4   2497                        aquaculture mooring manager       50
# 74   889                                      social worker       51
# 13  1405                                       graphologist       53
#
#                                    keywords_manual
# 68                         art & media technicians
# 72                         art & media technicians
# 2                          art & media technicians
# 65                         art & media technicians
# 64                         art & media technicians
# 70           creative managers & graphic designers
# 71           creative managers & graphic designers
# 46                                       perfomers
# 52               instructors & vocational teachers
# 39               instructors & vocational teachers
# 38               instructors & vocational teachers
# 0                                  textile workers
# 17             food & tobacco production operators
# 15             food & tobacco production operators
# 19             food & tobacco production operators
# 20             food & tobacco production operators
# 21             food & tobacco production operators
# 22             food & tobacco production operators
# 23             food & tobacco production operators
# 18             food & tobacco production operators
# 24             food & tobacco production operators
# 14             food & tobacco production operators
# 26             food & tobacco production operators
# 27             food & tobacco production operators
# 28             food & tobacco production operators
# 25             food & tobacco production operators
# 16             food & tobacco production operators
# 11                 doctors & specialist therapists
# 10                 doctors & specialist therapists
# 42             healthcare technicians & scientists
# 44             healthcare technicians & scientists
# 43             healthcare technicians & scientists
# 56              naturopathic & physical therapists
# 41              naturopathic & physical therapists
# 12  ict system engineers, adminstrators & managers
# 9   ict system engineers, adminstrators & managers
# 48                                    data workers
# 8                                     data workers
# 7                 animal care workers & trainers
# 6                 animal care workers & trainers
# 5                 animal care workers & trainers
# 3                         animal husbandry workers
# 4                              aquaculture workers
# 74                                  social workers
# 13                            esoteric counsellors

# %% [markdown]
# ### Switch the labels and save the curated version as `v1_1`

# %%
# Level-2
for job_i in list(switch_labels.keys()):
    occ_clust.loc[job_i, 'level_2'] = switch_labels[job_i]
    new_clust_level_1 = clusters_level_2[clusters_level_2.level_2==switch_labels[job_i]].level_1.values[0]
    occ_clust.loc[job_i, 'level_1'] = new_clust_level_1

# %%
occ_clust.to_csv(data_folder + 'processed/clusters/ESCO_occupation_clusters_v1_1_curated.csv', index=False)

# %%
clusters_level_1 = pd.read_csv(data_folder + 'processed/clusters/ESCO_occupation_clusters_v1_LEVEL1_manual.csv')
clusters_level_2 = pd.read_csv(data_folder + 'processed/clusters/ESCO_occupation_clusters_v1_LEVEL2_manual.csv')

# Number of skills per cluster
clusters_level_1 = get_cluster_counts('level_1', clusters_level_1)
clusters_level_2 = get_cluster_counts('level_2', clusters_level_2)

clusters_level_1.to_csv(data_folder + 'processed/clusters/ESCO_occupation_clusters_v1_1_LEVEL1.csv', index=False)
clusters_level_2.to_csv(data_folder + 'processed/clusters/ESCO_occupation_clusters_v1_1_LEVEL2.csv', index=False)
