# %% [markdown]
# # Specific examples of transitions data

# %% [markdown]
# # 0. Import dependencies and inputs

# %%
# %run ../../notebook_preamble_Transitions.ipy

# %%
# Location to store transitions data
outputs_folder = f'{useful_paths.data_dir}processed/transitions/specific_examples/'

# File name to use for the specific examples
file_name = 'Data_example'

# First batch of transitions
path_to_val_data = data_folder + 'restricted/validation/nesta_output_16Dec.csv'
batch_results = pd.read_csv(path_to_val_data)

# %% [markdown]
# # 1. Prepare transitions data

# %% [markdown]
# ## 1.0 Specify transitions

# %% [markdown]
# ### Example 1: Generate transitions

# %%
# Example 1: Generate a collection of transitions (e.g. all transitions from hotel porter and hotel concierge)
transitions_df = trans_utils.get_transitions(origin_ids=[732, 329], destination_ids='report')
transitions_df = transitions_df[transitions_df.is_safe_desirable].reset_index(drop=True)
transitions_df.info()

# %% [markdown]
# ### Example 2: Use the validation dataset

# %%
# Example 2: Add transition data using a pre-specified list of occupation pairs
validation_data = pd.read_csv(useful_paths.data_dir + 'processed/validation/Transitions_to_validate_BATCH_1.csv')
transition_pairs = [(row.origin_id, row.destination_id) for j, row in validation_data.iterrows()]
validation_data.head(5)
# Out:
#    origin_id    origin_label  \
# 0         29  legal guardian
# 1         29  legal guardian
# 2         29  legal guardian
# 3         29  legal guardian
# 4         29  legal guardian
#
#                                   origin_description  destination_id  \
# 0  Legal guardians legally assist and support min...            2867
# 1  Legal guardians legally assist and support min...            1036
# 2  Legal guardians legally assist and support min...            2877
# 3  Legal guardians legally assist and support min...            2654
# 4  Legal guardians legally assist and support min...            1803
#
#                                   destination_label  \
# 0                            recreational therapist
# 1                                 social counsellor
# 2                                  social pedagogue
# 3  employment and vocational integration consultant
# 4                 special educational needs teacher
#
#                              destination_description  \
# 0  Recreational therapists offer treatment to per...
# 1  Social counsellors provide support and guidanc...
# 2  Social pedagogues provide care, support, and e...
# 3  Employment and vocational integration consulta...
# 4  Special educational needs teachers work with a...
#
#                             perfectly_matched_skills  \
# 0                                    listen actively
# 1  listen actively; maintain the trust of service...
# 2  apply person-centred care; support children's ...
# 3   give advice on personal matters; listen actively
# 4  disability care; assess the development of you...
#
#                             partially_matched_skills  \
# 0                                                NaN
# 1  encourage counselled clients to examine themse...
# 2  support the positiveness of youths; adolescent...
# 3  facilitate job market access; develop course o...
# 4  assist children with special needs in educatio...
#
#                                     unmatched_skills
# 0  maintain healthcare user data confidentiality;...
# 1  reflexion; perform therapy sessions; demonstra...
# 2  undertake continuous professional development ...
# 3  observe confidentiality; communicate by teleph...
# 4  special needs learning equipment; observe stud...

# %%
transition_pairs[0:5]
# Out:
# [(29, 2867), (29, 1036), (29, 2877), (29, 2654), (29, 1803)]

# %%
transitions_df = trans_utils.get_transition_data(transition_pairs)
# Out:
# Finding data for all transitions... Done!
# This took 32.01 seconds.

# %%
transitions_df.head(5)
# Out:
#    origin_id    origin_label  destination_id  \
# 0         29  legal guardian            2867
# 1         29  legal guardian            1036
# 2         29  legal guardian            2877
# 3         29  legal guardian            2654
# 4         29  legal guardian            1803
#
#                                   destination_label  similarity  \
# 0                            recreational therapist    0.370220
# 1                                 social counsellor    0.364106
# 2                                  social pedagogue    0.352374
# 3  employment and vocational integration consultant    0.333975
# 4                 special educational needs teacher    0.319810
#
#    is_jobzone_ok  is_earnings_ok  is_not_high_risk  is_safer  \
# 0           True            True              True      True
# 1           True            True              True      True
# 2           True            True              True     False
# 3           True            True              True      True
# 4           True            True              True      True
#
#    is_strictly_safe  ...    W_work  W_essential_skills  W_optional_skills  \
# 0              True  ...  0.536452            0.203989           0.203989
# 1              True  ...  0.654659            0.073114           0.073994
# 2             False  ...  0.579094            0.086090           0.165216
# 3              True  ...  0.549595            0.117440           0.119270
# 4              True  ...  0.506951            0.019986           0.245352
#
#    W_activities  W_work_context  sim_category  is_viable  is_desirable  \
# 0      0.340975        0.731929    min_viable       True          True
# 1      0.513570        0.795748    min_viable       True          True
# 2      0.374458        0.783730    min_viable       True          True
# 3      0.374365        0.724825    min_viable       True          True
# 4      0.305689        0.708213    min_viable       True          True
#
#    is_safe_desirable  is_strictly_safe_desirable
# 0               True                        True
# 1               True                        True
# 2               True                       False
# 3               True                        True
# 4               True                        True
#
# [5 rows x 25 columns]

# %% [markdown]
# ## 1.1 Table of transitions

# %%
# Select only the desired columns
transitions_table = transitions_df[[
    'origin_id', 'origin_label', 'destination_id', 'destination_label',
    'similarity', 'W_essential_skills', 'W_optional_skills', 'W_activities', 'W_work_context',
    'sim_category', 'is_viable', 'is_desirable', 'is_safe_desirable']]

transitions_table.sample(5)
# Out:
#     origin_id     origin_label  destination_id  \
# 6         329  hotel concierge            2526
# 13        329  hotel concierge            2816
# 18        329  hotel concierge             841
# 7         329  hotel concierge             853
# 19        329  hotel concierge            1746
#
#                     destination_label  similarity  W_essential_skills  \
# 6                   funeral attendant    0.394271            0.250636
# 13            advertising sales agent    0.309892            0.064916
# 18            advertising media buyer    0.304007            0.097814
# 7   hospitality entertainment manager    0.361079            0.182806
# 19              travel agency manager    0.303329            0.130284
#
#     W_optional_skills  W_activities  W_work_context sim_category  is_viable  \
# 6            0.253230      0.484054        0.589165   min_viable       True
# 13           0.138624      0.271170        0.764860   min_viable       True
# 18           0.154458      0.215535        0.748219   min_viable       True
# 7            0.300343      0.204324        0.756844   min_viable       True
# 19           0.196919      0.122942        0.763171   min_viable       True
#
#     is_desirable  is_safe_desirable
# 6           True               True
# 13          True               True
# 18          True               True
# 7           True               True
# 19          True               True

# %% [markdown]
# Notes: The column `similarity` stores the combined similarity measure, i.e. the average of the four different similarity measures described in the Mapping Career Causeways report. These are also provided in the columns `W_{x}`).
#
# Column `sim_category` indicates whether the combined similarity is above 0.4 ('highly viable') or only between 0.3 and 0.4 ('minimally viable').
#
# The columns `is_viable`, `is_desirable`, `is_safe_desirable` should be clear (see the report for more details).

# %% [markdown]
# ### Export transitions

# %%
transitions_table.to_csv(f'{outputs_folder}{file_name}_Transitions.csv', index=False)

# %% [markdown]
# ## 1.2 Table of occupational profiles

# %%
# Select all IDs involved in the transitions
all_ids = set(transitions_table.origin_id.to_list()).union(set(transitions_table.destination_id.to_list()))

# %%
# Occupational profiles
occ_profiles = data.occ_report[data.occ_report.id.isin(all_ids)]
occ_profiles.sample(5)
# Out:
#         id concept_type                                        concept_uri  \
# 467    841   Occupation  http://data.europa.eu/esco/occupation/4795d4e3...
# 1133  2019   Occupation  http://data.europa.eu/esco/occupation/aaeec9a7...
# 185    329   Occupation  http://data.europa.eu/esco/occupation/1ae8d28e...
# 1191  2120   Occupation  http://data.europa.eu/esco/occupation/b39a74a2...
# 510    925   Occupation  http://data.europa.eu/esco/occupation/4d750b7f...
#
#               preferred_label  isco_level_1  isco_level_2  isco_level_3  \
# 467   advertising media buyer             2            24           243
# 1133      ICT help desk agent             3            35           351
# 185           hotel concierge             4            42           422
# 1191  railway station manager             1            13           132
# 510   social security officer             3            33           335
#
#       isco_level_4  is_top_level  job_zone  ...  \
# 467           2431          True       4.0  ...
# 1133          3512          True       3.0  ...
# 185           4229          True       3.0  ...
# 1191          1324          True       4.0  ...
# 510           3353          True       3.0  ...
#
#                                         onet_occupation  level_1  level_2  \
# 467   purchasing agents, except wholesale, retail, a...        5       24
# 1133                  computer user support specialists        2       12
# 185                                          concierges        2       11
# 1191                            transportation managers        2       13
# 510       eligibility interviewers, government programs        1        8
#
#       skills_based_sector_code  sub_sector_code  \
# 467                          6              6.2
# 1133                         3              3.2
# 185                          3              3.1
# 1191                         3              3.3
# 510                          2              2.3
#
#                     skills_based_sector                           sub_sector  \
# 467                arts & media workers  journalists, publishers & composers
# 1133           sales & services workers             customer representatives
# 185            sales & services workers    food, cleaning & services workers
# 1191           sales & services workers             shop & services managers
# 510   business & administration workers   assistants, clerks & legal workers
#
#       remote_labor_index  physical_proximity exposure_score
# 467                  NaN              0.3700            NaN
# 1133            0.647059              0.6375       0.474342
# 185             0.142857              0.6525       0.747854
# 1191            0.651163              0.4150       0.380483
# 510             0.923077              0.5575       0.207086
#
# [5 rows x 31 columns]

# %% [markdown]
# Please select the columns, which you find are the most relevant. For more information about the column data, please see [here](https://github.com/nestauk/mapping-career-causeways/tree/main/supplementary_online_data/transitions#number-of-transition-options-for-esco-occupations).

# %%
occ_profiles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20 entries, 25 to 1564
# Data columns (total 31 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   id                        20 non-null     int64
#  1   concept_type              20 non-null     object
#  2   concept_uri               20 non-null     object
#  3   preferred_label           20 non-null     object
#  4   isco_level_1              20 non-null     int64
#  5   isco_level_2              20 non-null     int64
#  6   isco_level_3              20 non-null     int64
#  7   isco_level_4              20 non-null     int64
#  8   is_top_level              20 non-null     bool
#  9   job_zone                  20 non-null     float64
#  10  education_level           20 non-null     float64
#  11  related_work_experience   20 non-null     float64
#  12  on_the_job_training       20 non-null     float64
#  13  annual_earnings           20 non-null     float64
#  14  total_paid_hours          20 non-null     float64
#  15  employment_count          20 non-null     float64
#  16  employment_share          20 non-null     float64
#  17  risk                      20 non-null     float64
#  18  prevalence                20 non-null     float64
#  19  risk_category             20 non-null     object
#  20  onet_code                 20 non-null     object
#  21  onet_occupation           20 non-null     object
#  22  level_1                   20 non-null     int64
#  23  level_2                   20 non-null     int64
#  24  skills_based_sector_code  20 non-null     int64
#  25  sub_sector_code           20 non-null     float64
#  26  skills_based_sector       20 non-null     object
#  27  sub_sector                20 non-null     object
#  28  remote_labor_index        18 non-null     float64
#  29  physical_proximity        20 non-null     float64
#  30  exposure_score            18 non-null     float64
# dtypes: bool(1), float64(14), int64(8), object(8)
# memory usage: 4.9+ KB

# %% [markdown]
# ### Export profiles

# %%
occ_profiles.to_csv(f'{outputs_folder}{file_name}_Occupation_profiles.csv', index=False)

# %% [markdown]
# ## 1.3 Skills matching data for specific transitions

# %%
# Choose a row of the transition table
row = 0

# Get skills matches
skills_matching = trans_utils.show_skills_overlap(transitions_table.loc[row].origin_id,
                                                  transitions_table.loc[row].destination_id,
                                                  skills_match='optional',
                                                  verbose=True)

# Export the skills matching table
skills_matching.to_csv(f'{outputs_folder}{file_name}_Skills_match_{row}.csv', index=False)

skills_matching
# Out:
# from hotel porter (id 732) to doorman/doorwoman (id 807)
# --------
# 6/6 destination skills matched
# NLP-adjusted overlap = 1.00 (total combined similarity: 0.77)
#    origin_skill_id                         origin_skill  destination_skill_id  \
# 0              832  comply with food safety and hygiene                   832
# 1             5243                 park guest's vehicle                  5243
# 2             6288            maintain customer service                  6288
# 3             9640    assist clients with special needs                  9640
# 4            11901                    detect drug abuse                 11901
# 5             2052                         greet guests                  2052
#
#                      destination_skill  similarity  score
# 0  comply with food safety and hygiene         1.0  0.998
# 1                 park guest's vehicle         1.0  0.998
# 2            maintain customer service         1.0  0.998
# 3    assist clients with special needs         1.0  0.998
# 4                    detect drug abuse         1.0  0.998
# 5                         greet guests         1.0  0.998

# %%
# Extra: You may also want to get some reference data on the skills (links to the ESCO database)
all_skills_ids = set(skills_matching.origin_skill_id.to_list()).union(set(skills_matching.destination_skill_id.to_list()))
data.skills[data.skills.id.isin(all_skills_ids)]
# Out:
#                    concept_type  \
# 832    KnowledgeSkillCompetence
# 2052   KnowledgeSkillCompetence
# 5243   KnowledgeSkillCompetence
# 6288   KnowledgeSkillCompetence
# 9640   KnowledgeSkillCompetence
# 11901  KnowledgeSkillCompetence
#
#                                              concept_uri        skill_type  \
# 832    http://data.europa.eu/esco/skill/0ff99f51-40d9...  skill/competence
# 2052   http://data.europa.eu/esco/skill/26a6e6d2-1c9a...  skill/competence
# 5243   http://data.europa.eu/esco/skill/624fc483-e30e...  skill/competence
# 6288   http://data.europa.eu/esco/skill/75dfe1ee-5935...  skill/competence
# 9640   http://data.europa.eu/esco/skill/b6b2e665-1085...  skill/competence
# 11901  http://data.europa.eu/esco/skill/e2c81781-19c8...  skill/competence
#
#         reuse_level                      preferred_label  \
# 832    cross-sector  comply with food safety and hygiene
# 2052   cross-sector                         greet guests
# 5243   cross-sector                 park guest's vehicle
# 6288   cross-sector            maintain customer service
# 9640   cross-sector    assist clients with special needs
# 11901  cross-sector                    detect drug abuse
#
#                                               alt_labels  \
# 832    comply with hygiene and food safety\ncomply wi...
# 2052   offer guests a warm welcome\nwelcome customers...
# 5243   drive customers' cars and manoeuvre into a par...
# 6288   ensure professional service\nmaintain serving ...
# 9640   handle participants with special needs\nassist...
# 11901  identify substance dependence\ndetect alcohol ...
#
#                                              description     id     code  \
# 832    Respect optimal food safety and hygiene during...    832   S3.3.1
# 2052   Welcome guests in a friendly manner in a certa...   2052   S3.4.4
# 5243   Line up guests' vehicles safely and efficientl...   5243   S8.2.2
# 6288   Keep the highest possible customer service and...   6288  A1.12.3
# 9640   Aid clients with special needs following relev...   9640   S3.4.4
# 11901  Identify people under excessive use of alcohol...  11901   S3.3.0
#
#       skill_category level_1 level_2  level_3  \
# 832                S      S3    S3.3   S3.3.1
# 2052               S      S3    S3.4   S3.4.4
# 5243               S      S8    S8.2   S8.2.2
# 6288               A      A1   A1.12  A1.12.3
# 9640               S      S3    S3.4   S3.4.4
# 11901              S      S3    S3.3   S3.3.0
#
#                                        level_title  \
# 832    complying with health and safety procedures
# 2052        providing general assistance to people
# 5243                        driving light vehicles
# 6288           provide high quality client service
# 9640        providing general assistance to people
# 11901                     protecting and enforcing
#
#                                               level_href  \
# 832    https://ec.europa.eu/esco/api/resource/concept...
# 2052   https://ec.europa.eu/esco/api/resource/concept...
# 5243   https://ec.europa.eu/esco/api/resource/concept...
# 6288   https://ec.europa.eu/esco/api/resource/concept...
# 9640   https://ec.europa.eu/esco/api/resource/concept...
# 11901  https://ec.europa.eu/esco/api/resource/concept...
#
#                                       level_uri
# 832     http://data.europa.eu/esco/skill/S3.3.1
# 2052    http://data.europa.eu/esco/skill/S3.4.4
# 5243    http://data.europa.eu/esco/skill/S8.2.2
# 6288   http://data.europa.eu/esco/skill/A1.12.3
# 9640    http://data.europa.eu/esco/skill/S3.4.4
# 11901   http://data.europa.eu/esco/skill/S3.3.0

# %% [markdown]
# ## 2. Data Sample export

# %%
batch_results = batch_results.set_index('subject_ids')

rows = sample_transitions_df[['transition_id', 'origin_id', 'destination_id']].iterrows()

skills_matches = []

for _, (i, origin_id, destination_id) in rows:
    skills_matching = trans_utils.show_skills_overlap(origin_id, destination_id, 
                                                      skills_match='optional', verbose=False)
    skills_matching['transition_id'] = i
    skills_matches.append(skills_matching)
    
skills_matches = pd.concat(skills_matches, axis=0)

# %%
transition_mean = batch_results.groupby('subject_ids')['feasibility_1-5'].mean()
transitions = batch_results.reset_index().drop_duplicates('subject_ids').set_index('subject_ids')

export_jobs = ['user interface developer', 'lottery cashier', 
               'community health worker', 'sales support assistant', 
               'travel agent', 'postman/postwoman', 'real estate surveyor',
               'investment clerk', 'financial analyst', 'packaging production manager'
              ]

sample_transitions = (transitions
                      .reset_index()
                      .set_index('origin_label')
                      .loc[export_jobs]
                      .reset_index()
                      .set_index('subject_ids'))

# %%
sample_transitions = sample_transitions.merge(transition_mean, left_index=True, 
                                              right_index=True, how='inner', 
                                              suffixes=('_raw', '_mean')
                                             )

sample_transitions = sample_transitions[sample_transitions['feasibility_1-5_mean'] > 2]

# %%
with open(data_folder + 'restricted/validation/data_sample_ids.txt', 'w') as f:
    for l in [str(tuple(r)) for r in sample_transitions[['origin_id', 'destination_id']].to_numpy()]:
        f.write(l + '\n')

# %%
from ast import literal_eval

# %%
with open(data_folder + 'restricted/validation/data_sample_ids.txt', 'r') as f:
    sample_ids = f.read().splitlines()
    
sample_ids = [literal_eval(l) for l in sample_ids]

# %% [markdown]
# ### 2.1 Sample Transitions

# %%
sample_transitions_df = trans_utils.get_transition_data(sample_ids)
# Out:
# Finding data for all transitions... Done!
# This took 0.77 seconds.

# %%
sample_transitions_df = sample_transitions_df.reset_index().rename(columns={'index': 'transition_id'})

# %% [markdown]
# ### 2.2 Sample Job Profiles

# %%
# Select all IDs involved in the transitions
all_ids = set(sample_transitions_df.origin_id.to_list()).union(set(sample_transitions_df.destination_id.to_list()))

# %%
# Occupational profiles
sample_occ_profiles = data.occ_report[data.occ_report.id.isin(all_ids)]
sample_occ_profiles.sample(5)
# Out:
#         id concept_type                                        concept_uri  \
# 1337  2386   Occupation  http://data.europa.eu/esco/occupation/c94f3565...
# 951   1702   Occupation  http://data.europa.eu/esco/occupation/8d9ec84d...
# 86     152   Occupation  http://data.europa.eu/esco/occupation/0c408028...
# 1364  2440   Occupation  http://data.europa.eu/esco/occupation/cee31c49...
# 977   1746   Occupation  http://data.europa.eu/esco/occupation/9358775a...
#
#                   preferred_label  isco_level_1  isco_level_2  isco_level_3  \
# 1337            programme manager             1            12           121
# 951             database designer             2            25           252
# 86                delivery driver             8            83           832
# 1364  real estate leasing manager             3            33           333
# 977         travel agency manager             1            14           143
#
#       isco_level_4  is_top_level  job_zone  ...  \
# 1337          1213          True       4.0  ...
# 951           2521          True       4.0  ...
# 86            8322          True       2.0  ...
# 1364          3334          True       4.0  ...
# 977           1439          True       4.0  ...
#
#                                         onet_occupation  level_1  level_2  \
# 1337                    general and operations managers        1        6
# 951                                 database architects       11       47
# 86             light truck or delivery services drivers        0        3
# 1364  property, real estate, and community associati...        1        7
# 977                                      sales managers        2       13
#
#       skills_based_sector_code  sub_sector_code  \
# 1337                         2              2.1
# 951                         12             12.3
# 86                           1              1.4
# 1364                         2              2.2
# 977                          3              3.3
#
#                                     skills_based_sector  \
# 1337                  business & administration workers
# 951                                         ict workers
# 86    technicians, construction, transport & securit...
# 1364                  business & administration workers
# 977                            sales & services workers
#
#                                         sub_sector remote_labor_index  \
# 1337  process managers, supervisors & coordinators           0.705882
# 951                                   data workers           0.735849
# 86                    transport & security workers           0.333333
# 1364       accounting & financial services workers           0.631579
# 977                       shop & services managers           0.750000
#
#      physical_proximity exposure_score
# 1337             0.5525       0.403113
# 951              0.4575       0.347634
# 86               0.6675       0.667083
# 1364             0.5100       0.433468
# 977              0.4775       0.345507
#
# [5 rows x 29 columns]

# %% [markdown]
# ### 2.3 Sample Skills

# %%
skills_matches.head()
# Out:
#   origin_skill_id                                 origin_skill  \
# 0            8359  tools for software configuration management
# 1            2343                 use software design patterns
# 2            6473                   develop software prototype
# 3            1954                               debug software
# 4            1778                         computer programming
#
#    destination_skill_id                            destination_skill  \
# 0                  8359  tools for software configuration management
# 1                  2343                 use software design patterns
# 2                  6473                   develop software prototype
# 3                  1954                               debug software
# 4                  1778                         computer programming
#
#    similarity  score  transition_id
# 0         1.0  0.998              0
# 1         1.0  0.998              0
# 2         1.0  0.998              0
# 3         1.0  0.998              0
# 4         1.0  0.998              0

# %%
# Extra: You may also want to get some reference data on the skills (links to the ESCO database)
sample_skills_ids = (set(skills_matches.origin_skill_id.to_list())
                     .union(set(skills_matches.destination_skill_id.to_list())))

sample_skill_profiles = data.skills[data.skills.id.isin(sample_skills_ids)]

# %%
sample_skill_profiles.head()
# Out:
#                 concept_type  \
# 2   KnowledgeSkillCompetence
# 7   KnowledgeSkillCompetence
# 31  KnowledgeSkillCompetence
# 58  KnowledgeSkillCompetence
# 70  KnowledgeSkillCompetence
#
#                                           concept_uri        skill_type  \
# 2   http://data.europa.eu/esco/skill/000709ed-2be5...  skill/competence
# 7   http://data.europa.eu/esco/skill/000f1d3d-220f...         knowledge
# 31  http://data.europa.eu/esco/skill/00e53a0a-c0ba...  skill/competence
# 58  http://data.europa.eu/esco/skill/016cee6c-9e95...  skill/competence
# 70  http://data.europa.eu/esco/skill/01c03003-516d...  skill/competence
#
#         reuse_level                   preferred_label  \
# 2   sector-specific   apply anti-oppressive practices
# 7   sector-specific                           Haskell
# 31  sector-specific   guarantee customer satisfaction
# 58  sector-specific         assess railway operations
# 70     cross-sector  advise on construction materials
#
#                                            alt_labels  \
# 2   apply non-oppressive practices\napply an anti-...
# 7                                                 NaN
# 31  to guarantee customer satisfaction\nensure cus...
# 58  appraise railway operations\nevaluate railway ...
# 70  giving of advice on construction materials\ngi...
#
#                                           description  id     code  \
# 2   Identify oppression in societies, economies, c...   2   S3.3.0
# 7   The techniques and principles of software deve...   7   K6.0.3
# 31  Handle customer expectations in a professional...  31  A1.12.3
# 58  Review and study existing railroad equipment, ...  58   S2.1.1
# 70  Provide advice on and test a wide range of con...  70   S1.5.3
#
#    skill_category level_1 level_2  level_3  \
# 2               S      S3    S3.3   S3.3.0
# 7               K      K6    K6.0   K6.0.3
# 31              A      A1   A1.12  A1.12.3
# 58              S      S2    S2.1   S2.1.1
# 70              S      S1    S1.5   S1.5.3
#
#                                           level_title  \
# 2                            protecting and enforcing
# 7   software and applications development and anal...
# 31                provide high quality client service
# 58                          conducting investigations
# 70                  advising on products and services
#
#                                            level_href  \
# 2   https://ec.europa.eu/esco/api/resource/concept...
# 7   https://ec.europa.eu/esco/api/resource/concept...
# 31  https://ec.europa.eu/esco/api/resource/concept...
# 58  https://ec.europa.eu/esco/api/resource/concept...
# 70  https://ec.europa.eu/esco/api/resource/concept...
#
#                                    level_uri
# 2    http://data.europa.eu/esco/skill/S3.3.0
# 7    http://data.europa.eu/esco/isced-f/0613
# 31  http://data.europa.eu/esco/skill/A1.12.3
# 58   http://data.europa.eu/esco/skill/S2.1.1
# 70   http://data.europa.eu/esco/skill/S1.5.3
